# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Борис, привет!</b>
#
# Меня зовут Евгений Головин, я буду ревьюером твоего проекта. Если ты не против, то предлагаю посмотрить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В ходе работы я оставил тебе комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы :)
#
# <div class="alert alert-info">
# <b>А свой помечай вот так, чтобы я его не потерял ;)</b>
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы :)
#
# На мои комменатрии можно и нужно реагировать, только делать это стоит так, чтобы твои и мои комменты не смешались: выделяй свои цветами, сильно отличающимися от моих.
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!

# %% [markdown]
# # Исследование данных о российском кинопрокате

# %% [markdown]
# Основная цель исследования - определить степень интереса зрителей к отечественным фильмам, получивших государственную поддержку, а также выявить тренды российского проката фильмов.
#
# В ходе выполения исследования будет проведена:
# - очистка и замена данных
# - анализ преобразованных данных и определение основных характристик, влияющих на сборы в прокате, рейтинг, популярность жанров, успешность студий, стран-производителей, режиссеров, продюссеров
# - анализ фильмов, получивших государственную поддержку, в части их популярности, эффективности затрат на производство, сравнение с аналогами

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №0:</b> В исходном ноутбуке выявлено некорректное отображение заголовков. Исправлено</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, понял тебя! По сути - введение есть, это отлично

# %% [markdown]
# ## Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

try:
    data_movies = pd.read_csv('/datasets/mkrf_movies.csv', sep=',')
except:
    data_movies = pd.read_csv('https://code.s3.yandex.net/datasets/datasets/mkrf_movies.csv', sep=',')
    
try:
    data_shows = pd.read_csv('/datasets/mkrf_shows.csv', sep=',')
except:
    data_shows = pd.read_csv('https://code.s3.yandex.net/datasets/datasets/mkrf_showscsv', sep=',')

# %%
data_shows.head()
# Out:
#     puNumber    box_office
# 0  111000113  2.450000e+03
# 1  111000115  6.104000e+04
# 2  111000116  1.530300e+08
# 3  111000117  1.226096e+07
# 4  111000118  1.636841e+08

# %%
data_movies.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
# ...

# %% [markdown]
# Данные загрузились корректно. Проверим "содержимое"

# %%
data_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
data_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %%
pd.DataFrame(round(data_movies.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_3519d_row0_col0,#T_3519d_row1_col0,#T_3519d_row2_col0,#T_3519d_row3_col0,#T_3519d_row4_col0,#T_3519d_row5_col0,#T_3519d_row6_col0,#T_3519d_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_3519d_row7_col0{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_3519d_row9_col0,#T_3519d_row10_col0,#T_3519d_row11_col0,#T_3519d_row12_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3519d_row13_col0,#T_3519d_row14_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }</style><table id="T_3519d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3519d_level0_row0" class="row_heading level0 row0" >title</th>
# ...

# %% [markdown]
# Лишь малая доля фильмов получили государственную поддержку (4%). В соответствии с описанием к заданию "столбец budget уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку." Т.е. пропуски в атрибутах, связанных с финансированием - не являются ошибкой или некорректными данным. В последствии можно будет заменить на 0.
# Часть данных о рейтинге, жанре (13%), продюссере (8%), режиссере и студии-производиетеле (менее 1%) пропущена.
#
# Судя по набору mkrf_shows (т.е. data_shows) сведения о сборах есть только у половины фильмов. Но мы пока не изучали набор на предмет наличия дубликатов и повторов

# %% [markdown]
# Ключом для объединения данных является атрибут puNumber (prоkatnoe udostovereniye Number, ин ауэр министри оф прачечная ви ар нот вэри затейливые он названия). Перед объединением проверим соответствие типов puNumber в двух наборах:
#
# - mkrf_movies - тип object
# - mkrf_shows - тип int
#
# В наборе mkrf_movies, т.е. в нашем data_movies приведем тип данных puNumber к типу int64, но скорее всего полностью у нас этого сделать не получится, т.к. среди номеров есть текстовые значения типа "нет" или "отсутствует". В оригинальном наборе открытых данных https://opendata.mkrf.ru/opendata/7705851331-register_movies/ есть значения "нет" среди номеров удостоверения (всего 2)
#
# Отметим, что наименование атрибута puNumber скорее всего не соответствует PEP8. Исправим на pu_number

# %%
data_movies = data_movies.rename(columns={'puNumber' : 'pu_number'})
data_shows = data_shows.rename(columns={'puNumber' : 'pu_number'})

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> По поводу всего, что было выше - отлично! Со всем пока согласен

# %%
data_movies['pu_number'] = data_movies['pu_number'].astype('int', errors='ignore')

# %%
data_movies.dtypes
# Out:
# title                     object
# pu_number                 object
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# dtype: object

# %%
data_movies_test = data_movies.query('pu_number == "нет"')

# %%
data_movies_test.head()
# Out:
#                                   title pu_number           show_start_date  \
# 1797  Курбан-роман. (История с жертвой)       нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 1797                    NaN     NaN              NaN     NaN    NaN

# %% [markdown]
# Действительно, среди pu_number есть 1-но значение, которое не может быть преобразовано в int. Удалим этот объект из набора. Тем более он всего 1 из 7486 и не содержит интересующей информации о государственной поддержке.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично, идем к поставленной цели)

# %%
#проверим кол-во объектов перед удалением
data_movies['pu_number'].count()
# Out:
# 7486

# %%
data_movies = data_movies.query('pu_number != "нет"')
data_movies['pu_number'] = data_movies['pu_number'].astype('int')

# %%
#количесвто изменилось ровно на 1, т.е. объект с puNumber = 'нет' удален
data_movies['pu_number'].count()
# Out:
# 7485

# %%
data_movies.dtypes
# Out:
# title                     object
# pu_number                  int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично!

# %% [markdown]
# Количество объектов уменьшидось ровно на 1, тип стал int64.
#
# Для объединения данных воспользуемся методом merge с типом слияния left. Так сохранятся все сведения из набора с фильмами data_movies, и не войдут лишние сведения, которые есть только в data_shows.
#
# Дополнительно проверим слияние.

# %%
data = pd.merge(data_movies, data_shows, on='pu_number', how='left')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   pu_number              7485 non-null   int64
#  2   show_start_date        7485 non-null   object
#  3   type                   7485 non-null   object
#  4   film_studio            7467 non-null   object
#  5   production_country     7483 non-null   object
#  6   director               7476 non-null   object
#  7   producer               6917 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Объединение прошло верно, отлично!

# %%
data.head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
# ...

# %% [markdown]
# ### Вывод по шагу 1
#
# Данные объединены. Итоговый dataframe содержит дополнительный столбец (атрибут) с указанием объемов сборов. На первый взгляд все данные из набора mkrf_shows (data_shows) загружены, т.к. кол-во непустых занчений box_office в итоговом датафрейме совпадает с исходным значением 3158.
#
# Также можно было не удалять объект с pu_number = "нет" и присвоить собственный номер. Хотя, административный регламент, регламентирующий порядок предоставления государственной услуги по выдаче прокатных удостоверений не содержит сведений о порядке и правилах присвоения номеров (Приказ Минкультуры России от 20.07.2012 N 787), в результате анализа структуры номера можно заключить, что номер присваивается по шаблону, где скорее всего первые две или три цифры - код страны производителя, 2 последние цифры - 2 последние цифры года производства. Т.о. номер фильма без номера может быть 217ХХХХХ14, т.к. в некоторых случаях 217 - код России, а 14 - год производства.
#
# Если подробно изучить структуру номера, то в целом можно по номеру восстановить отдельные пропуски, например жанр, если он заiифрован в номере.
#
# Также в результате последующего поиска по базе прокатных удостоверений фильма "Курбан-роман. (История с жертвой)" выявлено 2 записи в реестре с номером прокатного удостоверения "нет" (как в нашем наборе) и 111009614. Первые 3 цифры 111 являются кодом страны проихсождения "СССР", судя по других объектам.
#
# В итоге, можно заключить, что при наличии дополнительных ресурсов по номеру прокатного удостоверения в целом реально восстановить все пропущенные значения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все отлично)

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.dtypes
# Out:
# title                     object
# pu_number                  int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# box_office               float64
# dtype: object

# %% [markdown]
# Все типы данных соответствуют своим значениям, кроме типа show_start_date, который нужно привести к формату YYYY-MM-DD. Точное время не влияет на результаты дальнейшего анализа.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №0:</b> Только при выполнении шага 4 понял, что атрибут ratings имеет тип object и содержит значения в %.
#
# % может появится, если например, данные из системы выгружались в файл не важно какого формата (csv, json, xml, xlsx), потом обрабатывались в табличном редакторе для удаления лишних столбцов, строк и прочей подготовки данных. На этапе данной подготовки в табличном редакторе часть значений типа 0.ХХ могли распознаться как доля и автоматически переформатироваться в % (ИИ и алгоритмы же кругом, сами понимают что надо, можно ничего не делать, аналитику данных поручить компуктеру). Но такое возможно, если рейтинг на КиноПоиске может быть меньше 1. Судя по навигатору КиноПоиска - не может. Значит скорее всего необходимо преобразовать проценты ХХ% в число типа Х.Х
#
# Если значение записано как строка, то для преобразования надо удалить символ %, преобразовать float и разделить на 10</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Так, отлично)

# %%
data['ratings'].unique()
# Out:
# array(['7.2', '6.6', '6.8', '7.7', '8.3', '8.0', '7.8', '8.1', '7.1',
#        '6.0', '7.4', '5.8', '8.7', '6.3', '6.9', '5.0', '4.3', '7.3',
#        '7.0', '6.4', nan, '8.2', '7.5', '6.7', '7.9', '5.9', '6.2', '5.6',
#        '6.5', '2.4', '7.6', '6.1', '8.6', '8.5', '8.8', '5.5', '5.1',
#        '5.7', '5.4', '99%', '4.4', '4.5', '5.3', '4.1', '8.4', '2.6',
#        '3.8', '4.6', '4.8', '4.0', '3.0', '1.6', '4.2', '5.2', '4.7',
#        '4.9', '3.9', '2.7', '3.3', '2.9', '28%', '3.7', '1.4', '3.1',
#        '97%', '3.5', '3.2', '2.8', '1.5', '2.1', '2.5', '9.2', '3.4',
#        '1.1', '3.6', '83%', '64%', '91%', '94%', '62%', '79%', '90%',
#        '19%', '88%', '1.0', '89%', '1.3', '1.9', '1.8', '1.2', '1.7',
#        '9.0', '98%', '8.9', '9.1'], dtype=object)

# %%
#data['ratings'] = pd.to_numeric(data['ratings'], errors='coerce').astype('float64')
data['ratings'] = data['ratings'].astype('str').str.replace('%','').astype('str')
data['ratings'] = pd.to_numeric(data['ratings'], errors='ignore').astype('float64')
#data['ratings'] = data['ratings'].astype('float64')
data.loc[data['ratings'] > 10,'ratings']  = data['ratings'] / 10
data['ratings'].unique()
# Out:
# array([7.2, 6.6, 6.8, 7.7, 8.3, 8. , 7.8, 8.1, 7.1, 6. , 7.4, 5.8, 8.7,
#        6.3, 6.9, 5. , 4.3, 7.3, 7. , 6.4, nan, 8.2, 7.5, 6.7, 7.9, 5.9,
#        6.2, 5.6, 6.5, 2.4, 7.6, 6.1, 8.6, 8.5, 8.8, 5.5, 5.1, 5.7, 5.4,
#        9.9, 4.4, 4.5, 5.3, 4.1, 8.4, 2.6, 3.8, 4.6, 4.8, 4. , 3. , 1.6,
#        4.2, 5.2, 4.7, 4.9, 3.9, 2.7, 3.3, 2.9, 2.8, 3.7, 1.4, 3.1, 9.7,
#        3.5, 3.2, 1.5, 2.1, 2.5, 9.2, 3.4, 1.1, 3.6, 9.1, 9.4, 9. , 1.9,
#        1. , 8.9, 1.3, 1.8, 1.2, 1.7, 9.8])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   pu_number              7485 non-null   int64
#  2   show_start_date        7485 non-null   object
#  3   type                   7485 non-null   object
#  4   film_studio            7467 non-null   object
#  5   production_country     7483 non-null   object
#  6   director               7476 non-null   object
#  7   producer               6917 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   float64
# ...

# %%
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format='%Y-%m-%d')

# %%
data.head(2)
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
#
#         director                                   producer  \
# 0  Кевин Костнер  Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1      Е.Матвеев                                        NaN
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
#
#    budget financing_source  ratings                  genres  box_office
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично ,изменили тип данных у тех столбцов, что этого требовали. Хорошая работа!

# %% [markdown]
# ### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# Еще раз посмотрим на количество пропусков в датафрейме. Это понадобится для вывода и принятия решения о замене пропусков, а также выбора метода замены

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# refundable_support       7153
# nonrefundable_support    7153
# budget                   7153
# financing_source         7153
# box_office               4327
# genres                    975
# ratings                   966
# producer                  568
# film_studio                18
# director                    9
# production_country          2
# title                       0
# pu_number                   0
# show_start_date             0
# type                        0
# age_restriction             0
# dtype: int64

# %% [markdown]
# Узнаем про "диапазон" данных. Т.е. про самое старое и самое новой прокатное удостоверение в наборе. Даты выдачи прокатных удостоверений - 2010-2019 гг.

# %%
print(data['show_start_date'].min())
print(data['show_start_date'].max())
# Out:
# 2010-01-11 12:00:00+00:00
# 2019-12-30 12:00:00+00:00

# %% [markdown]
# Узнаем о количестве уникальных значений в атрибутах набора. Нас ждет конкретная чистка и поиск неявных соответствий.

# %%
for column in data.columns:
    print(column, ':', data[column].nunique())
# Out:
# title : 6771
# pu_number : 7483
# show_start_date : 1964
# type : 8
# film_studio : 5490
# production_country : 950
# director : 4811
# producer : 5349
# age_restriction : 5
# refundable_support : 34
# nonrefundable_support : 75
# budget : 290
# financing_source : 3
# ratings : 84
# genres : 742
# box_office : 2938

# %% [markdown]
# Т.е. судя по всему:
# - часть фильмов имеют одинаковые наименования, но не факт, что это одинаковые фильмы
# - наименования стран-производителей указаны как попало, потому что их число больше официально признанных ООН стран
# - наименования студий также записаны скорее всего как угодно, только не уникальными наименованиями + списком студий
# - жанры также не уникальны и записаны списками или перечнем жанров в одной "ячейке". В соответствии с КиноПоиском всего есть 32 жанра фильмов. Классификатор IMDB содержит 21 наименование жанров (а у нас 742)
#
# Хотя, все это было и так понятно, после просмотра первых строк набора. *Работа с уникальными значениями далее в п.2.4-2.6*

# %% [markdown]
# **Есть вполне объяснимые пропуски, которые не стоит заполнять:**
#
# - **refundable_support, nonrefundable_support, budget, financing_source** 7153 пропуска из 7485. Замена на данном этапе не требуется, т.к. в соответствии с описанием в набора данных и задания можно сделать вывод, что в исходной выгрузке отображена вся необходимая информация о фильмах с бюджетным финансированием. Всего таких записей в исходном файле 332.
#
# *В открытом доступе в системе ЕАИС https://ekinobilet.fond-kino.ru/government-support/ содержится информация о 484 фильмах и их сериях (многосерийных фильмах), получивших государственную поддержку Министерства культуры и Фонда Кино с 2015 года. Анализируемый набор содержит сведения о прокатных удостоверениях фильмов, выданных с начала 2010 года. С 2010 года также начала действовать система государственной поддержки отечественного кинматографа.*
#
# *В целом, порядок величин соответствует, поэтому замена пропусков не требуется. Либо надо отдельно добавить в дата фрейм информацию из оригинального источника, но в данный момент набор данных о государственной поддержке в открытом доступе не опубликован https://opendata.mkrf.ru/opendata/7705851331-movie_support, в официальном источнике ссылаются на сайт ЕАИС*
#
# *Также остуствуют сведения о количестве мер государственной поддержки (количестве фильмов с 2010 года) в официальных источниках статистической информации, например в ЕМИССе и на сайте Росстата. Отдельные данные есть в новостях и сообщениях СМИ, порядок которых (400-500 или по 100-150 поддержанных фильмов в год) соответствует количеству из исследуемого набора*
#
# На этапе исследовательского анализа данных значения NaN в атрибутах refundable_support, nonrefundable_support, financing_source, budget будут заменены на новые значения (0 и "нет государственного финансирования") для корректного выполнения расчетов
#
# - **box_office** 4327 пропусков. Скорее всего с этими отсутствющими данными ничего сделать нельзя. Оригинальный набор данных, размещенных на Портале открытых данных Минкульутры России не содержит соответсвующие сведения. Статистика, размещенная на сайте ЕАИС не позволяет собрать достаточное количество данных, чтобы расситать общий объем сборов для каждого фильма, т.к. функционал системы отображает лишь топ-20 фильмов за выбранный период. Чисто теоретически можно спрасить данные с сайта ЕАИС, но в описании к набору данных и заданию не указано, за какой период отражены "сборы в рублях" в атрибуте box_office в наборе mkrf_shows (скорее всего 2010-2019 гг)
#
# **Следующие пропуски, возможно, необходимо заполнить:**
#
# - **genres** 975 пропусков. Часть пропусков можно будет заменить на самый популярный жанр, который соответствует режиссеру/продюссеру/студии. Или заменить на жанр "Прочие" или "Неопределено", "Прочие/Неопределено"
# - **ratings** 966 пропусков. 1) Пропуски можно заменить на среднее/медианное значение рейтинга аналогичных фильмов режиссера/продюссера/студии в данном жанре. 2) С помощью парсинга КиноПоиска можно выгрузить данные о рейтинге фильма по наименованию/режиссеру (но мы еще не изучали парсинг данных). Я его могу сделать на коленке в другой более знакомой среде, но не буду, простите извините меня в Минкульутре=)
#
# Но! Данные пропуски можно корректно заменить, если в соответсвующих полях будут стоять уникальные значения. Предлагаю пока остановится на замене пропусков в genre на служеюное значение "Прочие/Неопределено", а ratings оставить как есть. После создания уникальных списков наименований жанров, режиссеров, продюссеров, студий, стран-происхождения можно будет заменить данные служебные и пустые значения на новые.
#
# **Данные пропуски можно удалить пользуясь советом, полученным на ревью:"✔️Комментарий от ревьюера №1
# Если пропусков меньше 5-8% их лучше сразу удалять, дабы сэкономить время" , но:**
#
# - **producer** 568 пропусков. Замена по аналогии и соответствию продюссер-студия-режиссер
# - **film_studio** 18 пропусков. Замена по аналогии и соответствию студия-продюссер-режиссер
# - **director** 9 пропусков. Для замены данных пропусков можно воспользоваться поиском в любой открытой базе данных для нахождения информации о режиссере фильма и ручной замены.
# - **production_country** 2 пропуска. Для замены данных пропусков можно воспользоваться поиском в любой открытой базе данных для нахождения страны производства фильма и ручной замены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все отлично, согласен, что в некоторых столбцах уместно ввести заглушку, а некоторые просто оставить как есть

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Только отмечу важную вещь: те самые 5-8%, про которые тебе говорил ревьювер, абсолютно верны, но нужно понимать, что после уаления прпоусков, чистки выбросов, в общем после приведения датафрейма в пригодный для работы вид 90% от его исходного размера должны быть сохранены

# %% [markdown]
# div class="alert alert-info"> <b>Комментарий студента №1:</b> Поэтому и не удалял</div>

# %% [markdown]
# Начнем с конца

# %% [markdown]
# **2.2.1 Production_country**

# %%
data[data['production_country'].isna()]
# Out:
#                                                   title  pu_number  \
# 3185  Детский юмористический киножурнал "Ералаш. Ну ...  111001216
# 4440                           Мульт личности. Выпуск 5  214000410
#
#                show_start_date            type  \
# 3185 2016-02-09 12:00:00+00:00  Художественный
# 4440 2010-01-25 12:00:00+00:00  Художественный
#
#                           film_studio production_country  \
# 3185  ООО "Продюсерский центр ЕРАЛАШ"                NaN
# 4440                              NaN                NaN
#
#                                                director  \
# 3185  Р.Светлов, И.Магитон, А.Арутюнян, Л.Мирский, А...
# 4440                                                NaN
#
#                              producer                         age_restriction  \
# 3185  ООО "Продюсерский центр ЕРАЛАШ"  «0+» - для любой зрительской аудитории
# 4440                              NaN  «0+» - для любой зрительской аудитории
#
# ...

# %% [markdown]
# Нет нужды искать дополнительно информацию, т.к. страна-производитель у этих фильмов - Россия. Мультличности вышел в 2009 году, а ООО "... Ералаш" не мог существовать во времена СССР, потому что до 1995 года Ералаш выпускался Центральной киностудией детских и юношеских фильмов имени М. Горького.
#
# Произведем "ручную" замену значений

# %%
data.loc[4440, 'production_country'] = 'Россия'
data.loc[3185, 'production_country'] = 'Россия'

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, верно

# %% [markdown]
# **2.2.2 director, film_studio, producer**

# %% [markdown]
# Посмотрим на объекты, которые содержат эти пустые значения

# %%
data[data['director'].isna()]
# Out:
#                                                   title  pu_number  \
# 764   Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 1735                           Помпеи. Британский музей  126003413
# 3839                     Зур концерт (Большой концерт).  217027010
# 4051  Ганс Сэйфуллин "Авылым чишмэлэре. Ганс Сэйфулл...  217017310
# 4297                        Изге Вэли (Святой Валентин)  217020610
# 4414                          Bon Jovi. The Circle Tour  126001710
# 4440                           Мульт личности. Выпуск 5  214000410
# 4922  Георг Фридрих Гендель. Мессия. Оратория. Корол...  126001111
# 4941             Питер Гэбриэл и New Blood Orchestra 3D  126002711
#
#                show_start_date            type                   film_studio  \
# 764  2012-12-04 12:00:00+00:00          Прочие            Райзинг Алтернатив
# 1735 2013-09-11 12:00:00+00:00          Прочие  МортуСкрин, Британский музей
# ...

# %%
data[data['film_studio'].isna()]
# Out:
#                                          title  pu_number  \
# 1293                           Stars in Shorts  121011114
# 4440                  Мульт личности. Выпуск 5  214000410
# 6104                              Значит любит  111013818
# 6180                     Несейка. Младшая дочь  112007018
# 6378                              Ян Антонышев  112011818
# 6379                              Ян Антонышев  112011918
# 6398                     Доживем до каникул?..  111021918
# 6484                                До и После  112014418
# 6493            Калмыцкий геше Нгаванг Вангьял  113002018
# 6496                        Мой папа Чингисхан  112014918
# 6497                       В плену города грёз  112014818
# 6498                            Последнее фото  112014518
# 6506                              Мой селфхарм  113001918
# 6510            Обстоятельства места и времени  112015018
# 6637  Эрик Булатов. Моя Третьяковка, серии 1-2  113000319
# ...

# %% [markdown]
# Никакой особой зависимости между наименованием студии, режиссером и продюссером фильмов нет. Данные слегка неккоректны, т.к. наименование студии может быть записано в наименовании продюссера и наоброт. Т.е. "продюссер" в данном наборе это не всегда ФИО. Предлагаю в произвести замену пустых значений director и producer на "Джон Доу делает видео", пустых значений film_studio на "Студия Джон Доу делает видео". Бъюсь об заклад, что таких наименований в наборе нет. Это будут наши служебные наименования. Возможно, в последствии нас ждет какой-нибудь интересный результат, когда наш Джон Доу снял самые популярные фильмы, получив 100 руб. от государства.

# %%
data['director'] = data['director'].fillna('Джон Доу делает видео')
data['producer'] = data['producer'].fillna('Джон Доу делает видео')
data['film_studio'] = data['film_studio'].fillna('Студия Джон Доу делает видео')

# %% [markdown]
# Пропуски в значениях "режиссер", "продюссер", "студия" заполнены

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошо, договорились! Только давай не будем сильно заигрывать с такмим названиями заглушек)

# %% [markdown]
# **2.2.3 genres**

# %%
data['genres'] = data['genres'].fillna('Прочие/Неопределено')

# %%
#хоба!
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   pu_number              7485 non-null   int64
#  2   show_start_date        7485 non-null   datetime64[ns, UTC]
#  3   type                   7485 non-null   object
#  4   film_studio            7485 non-null   object
#  5   production_country     7485 non-null   object
#  6   director               7485 non-null   object
#  7   producer               7485 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   float64
# ...

# %% [markdown]
# #### Вывод по шагу 2.2
#
# Проведена замена пустых значений в атрибутах:
# - production_country в ручную на "Россия"
# - director, producer на служебное значение "Джон Доу делет видео"
# - film_studio на служебное значение "Студия Джон Доу делает видео"
# - genres на служебное значение "Прочие/Неопределено"
# - ratings преварительно решили изменить позже, после обработки других атрибутов (но это не точно)
#
# остальные пустые значения в других атрибутах не заменялись

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично!

# %% [markdown]
# ### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Полностью одинаковых и идентичных объектов с совпадающими атрибутами нет

# %%
for column in data.columns:
    print(column, data.duplicated(column).sum())
# Out:
# title 714
# pu_number 2
# show_start_date 5521
# type 7477
# film_studio 1994
# production_country 6535
# director 2673
# producer 2135
# age_restriction 7480
# refundable_support 7450
# nonrefundable_support 7409
# budget 7194
# financing_source 7481
# ratings 7400
# genres 6742
# box_office 4546

# %% [markdown]
# В отдельных столбцах есть дубликаты и пересечения. В основном все дубликаты объяснимы, кроме pu_number. Наименования у разных объектов могут быть одинаковые, т.к. названия фильмов могут совпадать, но это будут совершенно разные фильмы. Или прокатное удостоверение выдавались на один и тот же фильм разным правообладателям, прокатчикам, для разных целей. Есть примеры, когда  одинаковые фильмы получали в разное время различные прокатные удостоверения для демонстрации в разных сетях кинотеатров (вывод на основе поиска в оригинальном реестре). Например, фильм "Дракула" режиссера Френсиа Форда Копполы имеет 10 прокатных удостоверений, зарегистрирвоанных в официальном реестре

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Верно подмечено

# %%
data[data['pu_number'].duplicated()]
# Out:
#                                                   title  pu_number  \
# 4638  Иоанна - женщина на папском престоле /По роман...  221154310
# 5067                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4638   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5067  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# 4638  Германия - Великобритания - Италия - Испания  Зенке Вортманн
# 5067                                           США  Гарольд Реймис
#
#                                         producer  \
# 4638  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
# 5067             Джейн Розенталь, Паул Уэйнстейн
#
#                       age_restriction  refundable_support  \
# ...

# %%
display(data[data['pu_number'] == 221154310])
display(data[data['pu_number'] == 221054410])
# Out:
#                                                   title  pu_number  \
# 4637                   Как жениться и остаться холостым  221154310
# 4638  Иоанна - женщина на папском престоле /По роман...  221154310
#
#                show_start_date            type  \
# 4637 2010-12-17 12:00:00+00:00  Художественный
# 4638 2010-12-17 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4637  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4638   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
#
#                                 production_country        director  \
# 4637                                       Франция    Эрик Лартиго
# 4638  Германия - Великобритания - Италия - Испания  Зенке Вортманн
#
#                                         producer  \
# 4637                     Амандин Било, Алан Шаба
# 4638  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
#
#                       age_restriction  refundable_support  \
# ...

# %% [markdown]
# #### Вывод по шагу 2.3
#
# Каких либо особенностей в наличии дубликатов нет, кроме 2 одинаковых значений pu_number.
#
# Этим номерам действительно соответствуют 4 фильма из оригинального реестра Минкульутры. Изучение детальных сведений в реестре не выявило каки-либо особенностей в выдаче прокатных удостоверений. Каждое ПУ выдавались в разное время, но одному правообладателю. Административный регламент прдусамтривает выдачу одного ПУ на 1 произведение, поэтому не может такого быть, что 1 ПУ выдано на 2 фильма сразу. Скорее всего это ошибка внесения данных в реестр, а не выгрузки из неё.
#
# Дубликаты в номерах прокатных удостоверений оставлены без изменений, т.к. на дальнейший анализ это никак не влияет

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Согласен

# %% [markdown]
# ### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Создадим датафрейм, в котором будет отражена информация о количестве уникальных значений, количестве дубликатов и пропусков в разрезе атрибутов

# %%
a = []
b = []
c = []
d = ['type', 'film_studio','production_country', 'director', 'producer', 'age_restriction']

for column in d:
    a.append(data[column].nunique())

for column in d:
    b.append(data.duplicated(column).sum())
    
for column in d:
    c.append(data[column].isna().sum())

data_un_dupl = pd.DataFrame(list(zip(d,a,b,c)), columns=['name', 'unique', 'dupl', 'isna'])
data_un_dupl['frq'] = data_un_dupl['dupl'] / data_un_dupl['unique']
data_un_dupl.sort_values(by='unique', ascending=False).reset_index()
# Out:
#    index                name  unique  dupl  isna          frq
# 0      1         film_studio    5491  1994     0     0.363140
# 1      4            producer    5350  2135     0     0.399065
# 2      3            director    4812  2673     0     0.555486
# 3      2  production_country     950  6535     0     6.878947
# 4      0                type       8  7477     0   934.625000
# 5      5     age_restriction       5  7480     0  1496.000000

# %% [markdown]
# Посмотрим отдельно на каждый столбец

# %%
category_columns = ['type', 'film_studio', 'production_country', 'director', 'producer', 
           'age_restriction', 'financing_source', 'genres']
for column in category_columns:
    display(pd.DataFrame(data[column].value_counts().head(20)))
# Out:
#                             type
# Художественный              4519
#  Художественный             1389
# Анимационный                 828
# Прочие                       406
# Документальный               288
# Научно-популярный             53
#  Анимационный                  1
# Музыкально-развлекательный     1
#                                                     film_studio
# Киностудия "Мосфильм"                                       341
# ООО "Мульт в кино"                                           57
# Анимаккорд Лтд                                               23
# Студия Джон Доу делает видео                                 18
# ООО "Мульт в кино"                                           18
# ФГУП "ТПО "Киностудия "Союзмультфильм"                       16
# ООО "ТаББаК"                                                 15
# Р А И Синема                                                 14
# Опус Арте                                                    14
# ...

# %% [markdown]
# К основным проблемам категориальных столбцов можно отнести:
# - различное написание одинаковых наименование, использование лишних кавычек, например ФГУП "Киноконцерн "Мосфильм" и Киноконцерн "Мосфильм"
# - сокращение имен в ФИО
# - перечислений через запятую (ФИО, наименования студий), перечисления через разные разделители ",", ", ", "-", " - "
#
# Часть данных будет преобразована для анализа на шаге 2.6 и 3.4

# %%
display(data['type'].unique())
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', ' Художественный', ' Анимационный',
#        'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# **Т.о всего в столбце:**
# - type 6 категорий с корректными наименованиями и 2 категории с некорректными (' Художественный', ' Анимационный'). После замены некорректных значений должно остаться 6 категорий
# - наш Джон Доу стал самым плодотворным продюссером и одной из самых продуктивных студий
# - Жанр "Прочие/Неопределено" - самый крупный "класс" среди всех жанров. Также в столбце жанр много повторов и совмещений жанров
# - остальные категориальные столбцы не вызывают каких-либо нареканий
#
# Вполне возможно, что лишние пробелы присутсвуют во всех "категориальных" столбцах. Устраним лишние пробелы во всех столбцах.

# %%
for column in category_columns:
    data[column] = data[column].str.strip()
    
display(data['type'].unique())
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', 'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# #### Вывод по шагу 2.4
#
# Проведена замена ошибочных наименований категорий типов фильмов (type), содержащих лишние пробелы. Аналогичная очистка проведена также в остальных категориальных атрибутах

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично! Обе проблемы обозначены верно: и лишние пробелы, и целая тьма по сути дублирующих друг друга значений в некоторых столбцах

# %% [markdown]
# ### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
data.hist(figsize=(15,10), bins=100);

# %% [markdown]
# **Рассмотрим часть гистограмм отдельно**
#
# Также для дальнейшей обработки и наглядности изменим формат отображения чисел

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### Бюджет

# %%
#display(data['budget'].hist(bins=200, range=(0,150000000)))
plt.hist(data['budget']/10**6, bins=100, range=(0,1000))
plt.xlabel('млн руб.')
plt.ylabel('Количество')
display(data['budget'].describe())
# Out:
# count             332.00
# mean      127,229,716.68
# std       188,588,333.12
# min                 0.00
# 25%        42,000,000.00
# 50%        68,649,916.00
# 75%       141,985,319.50
# max     2,305,074,303.00
# Name: budget, dtype: float64

# %%
display(data['budget'].hist(bins=10, range=(0,1000)))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Виден пик на значении 0 (17 значений). Скорее всего в данных ошибка.
# Описание набора данных не содержит единиц измерения, но т.к. максимальное значение бюджета фильма составляет 2,3 млрд, то можно заключить, что единица измерения млрд руб.
#
# Есть отдельные пики. Природа таких пиков не ясна и скорее всего это реальнео распределение бюджета. При изменении масштаба видно, что это не является какой-то особенностью.
#
# Рассмотри отдельно фильмы, бюджет которых равен 0

# %%
display(data.query('budget == 0'))
# Out:
#                        title  pu_number           show_start_date  \
# 2052                     14+  111023614 2014-12-19 12:00:00+00:00
# 2057               Дуxless 2  111000415 2015-01-26 12:00:00+00:00
# 2471             Воин (2015)  111017315 2015-09-28 12:00:00+00:00
# 2531                 Бармен.  111009615 2015-05-26 12:00:00+00:00
# 2614     Савва. Сердце воина  114001715 2015-07-21 12:00:00+00:00
# 2683          Тряпичный союз  111010215 2015-06-08 12:00:00+00:00
# 2787      Срочно выйду замуж  111017115 2015-09-30 12:00:00+00:00
# 2873       Помню - не помню!  111004916 2016-03-01 12:00:00+00:00
# 3046  Любовь с ограничениями  111008216 2016-04-29 12:00:00+00:00
# 3564       Притяжение (2016)  111018116 2016-12-16 12:00:00+00:00
# 3674                Чудо-юдо  114001817 2017-06-27 12:00:00+00:00
# 3738                    Мифы  111004317 2017-06-07 12:00:00+00:00
# 5672                   Селфи  111012117 2018-02-01 12:00:00+00:00
# ...

# %% [markdown]
# У фильмов с "нулевым" бюджетом заполены данные об объемах возвратных и невозвратных средств государственной поддержки. В соответствии с Бюджетным кодексом РФ средства государственной поддержки предоставлются в виде субсидии на производство товаров, работ и услуг. Т.о. для фильмов  с нулевым бюджетом сумма возвратных и невозвратных средств в т.ч. будет являться "бюджетом" на производство фильмов. Целесообразно заполнить нулевые значения budget суммой refundable_support и nonrefundable_support

# %%
data.loc[data['budget'] == 0, 'budget'] = data['refundable_support'] + data['nonrefundable_support']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Так, абсолютно верно)

# %% [markdown]
# Проверим в целом, характерно ли для нашего набора то, что бюджет равен сумме объемов возвратных и невозратных средств. А также проверим, сколько вообще таких объектов в наборе. Для этого создадим тестовый датафрейм и проведем в нем дополнительные вычисления

# %%
data.pivot_table(index='type', values=['budget', 'refundable_support', 'nonrefundable_support'], aggfunc='sum')
# Out:
#                                       budget  nonrefundable_support  \
# type
# Анимационный                5,909,423,882.00       1,640,489,465.00
# Документальный                 33,000,000.00           3,000,000.00
# Музыкально-развлекательный              0.00                   0.00
# Научно-популярный                       0.00                   0.00
# Прочие                                  0.00                   0.00
# Художественный             37,689,811,522.00      14,618,198,847.00
#
#                             refundable_support
# type
# Анимационный                    930,000,000.00
# Документальный                            0.00
# Музыкально-развлекательный                0.00
# Научно-популярный                         0.00
# Прочие                                    0.00
# Художественный                3,009,000,000.00

# %%
data_test = data.loc[:,['pu_number', 'budget', 'refundable_support', 'nonrefundable_support']]
data_test['support'] = data_test['nonrefundable_support'] + data_test['refundable_support']
data_test.loc[data_test['support'] == data_test['budget']].count()
# Out:
# pu_number                17
# budget                   17
# refundable_support       17
# nonrefundable_support    17
# support                  17
# dtype: int64

# %% [markdown]
# Т.е. в целом для фильма не характерно то, что его бюджет складывается только из субсидий. Всего фильмов, бюжет которых равен сумме объемов возвратных и невозвратных средств - 17 и это те фильмы, для которых значение бюджета было равно 0 и изменено принудительно на сумму.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Оно и понятно, бюджет ведь состоит не только из гос поддержки

# %% [markdown]
# #### Сборы

# %%
#display(data['box_office'].hist(bins=100, range=(0,24000000)))
plt.hist(data['box_office']/10**6, bins=100, range=(0,100))
plt.xlabel('млн руб.')
plt.ylabel('Количество')
display(data['box_office'].describe())
# Out:
# count           3,158.00
# mean       76,478,696.16
# std       240,353,122.82
# min                 0.00
# 25%            86,239.00
# 50%         2,327,987.55
# 75%        23,979,671.02
# max     3,073,568,690.79
# Name: box_office, dtype: float64

# %%
display(data['box_office'].hist(bins=100, range=(0,20000)))
# Out:
# <AxesSubplot:>

# %%
display(data['box_office'].hist(bins=100, range=(0,2500)))
# Out:
# <AxesSubplot:>

# %%
data.query('box_office < 10000').count()
# Out:
# title                    539
# pu_number                539
# show_start_date          539
# type                     539
# film_studio              539
# production_country       539
# director                 539
# producer                 539
# age_restriction          539
# refundable_support         4
# nonrefundable_support      4
# budget                     4
# financing_source           4
# ratings                  514
# genres                   539
# box_office               539
# dtype: int64

# %% [markdown]
# Для ряда фильмов (24 шт.) указаны нулевые сборы. В целом такое возможно, особенно если фильм нигде не демонстрировался по разным причинам. Также сборы 539 фильмов составляют менее 10 тыс. руб. Зрители голосуют ногами, с другой стороны у этих фильмов проставлены рейтинги. Их бесплатно смотрели?

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Не уверен, думаю, что здесь закралась какая-нибдуь ошибка

# %% [markdown]
# #### Объемы средств государственной поддержки

# %%
#display(data['refundable_support'].hist(bins=10, range=(0,18000000)))
plt.hist(data['refundable_support']/10**6, bins=20, range=(0,100))
plt.xlabel('млн руб.')
plt.ylabel('Количество')
display(data['refundable_support'].describe())
# Out:
# count           332.00
# mean     11,864,457.83
# std      24,916,555.26
# min               0.00
# 25%               0.00
# 50%               0.00
# 75%      15,000,000.00
# max     180,000,000.00
# Name: refundable_support, dtype: float64

# %% [markdown]
# Значительное количество фильмов с нулевым объемом возвратных средств не является чем-то необычным. Т.е. в наборе просто указано реальное значение возрватных средств, равное 0. Аналогично с невозвратными средствами.

# %%
#display(data['nonrefundable_support'].hist(bins=10, range=(0,18000000)))
plt.hist(data['nonrefundable_support']/10**6, bins=20, range=(0,200))
plt.xlabel('млн руб.')
plt.ylabel('Количество')
display(data['nonrefundable_support'].describe())
# Out:
# count           332.00
# mean     48,980,988.89
# std      59,980,117.92
# min               0.00
# 25%      25,000,000.00
# 50%      30,000,000.00
# 75%      40,375,000.00
# max     400,000,000.00
# Name: nonrefundable_support, dtype: float64

# %% [markdown]
# Проверим общую динамику общего бюджета, государственной поддержки и сборов (без учета нулевых значений)

# %%
data.dropna().plot(x='show_start_date', y=['refundable_support', 'nonrefundable_support', 'budget', 'box_office'], style='o-', figsize=(20,10));

# %% [markdown]
# На графике видно, что иногда бюджет фильма превышает сборы, что в целом многое говорит о качестве произведений

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошо

# %% [markdown]
# #### Вывод по шагу 2.5
#
# Анализ количественных значений показал, что у ряда объектов были ошибки в значениях бюджета (стояли 0), но такого не может быть по определению, т.к. бюджет фильма также включает в себя государственную поддержку. Нулевой бюджет таких фильмов был заменен на сумму государственной поддержки.
#
# Иные колчиественные значения атрибутов каких-либо особенностей не имеют. Общие сборы фильмов могут быть равны 0 (для всех фильмов, у которых данное значение не NaN), аналогично для нулевых значений объемов государственной поддержки. Отдельные пики никак не характеризуют эти атрибуты.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Провели хорошую качественную работу

# %% [markdown]
# ### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
data['year'] = data['show_start_date'].dt.year

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# В результате манипуляций, проведенных в других пунктах и на основе предварительного просмотра значений атрибутов genres, director и др. можно утверждать, что данные атрибуты содержат в себе наименования жанров и ФИО, записанные через запятую.
# Создадим функцию, которая:
# - превращает значение атрибута в строку и превращает её в список из эелементов строки, разделенных разделителем ','
# - выделяет из списка элемент 0
#
# Применим данную функцию к столбцам genres и directror для создания новых столбцов, содержащих только первые элементы

# %%
def create_column(column):
    split_column = str(column).split(',')
    column = split_column[0]
    return column

data['genre_1'] = data['genres'].apply(create_column)
data['director_name'] = data['director'].apply(create_column)

# %% [markdown]
# Также можно было воспользоваться только методами строк, чтобы выделить превый элемент

# %%
#data['director_name'] = data['director'].str.split(',').str[0]
#data['genre_1'] = data['genres'].str.split(',').str[0]

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
data['state_support'] = data['refundable_support'] + data['nonrefundable_support'] #столец будет необходим в дальнейшем
data['state_support_share'] = (data['state_support']) / data['budget']

#display(data.dropna().plot(x='show_start_date', y=['refundable_support', 'nonrefundable_support', 'budget'], figsize=(20,10)))
display(data.pivot_table(index='year', values='state_support_share', aggfunc='mean'))
display(data.pivot_table(index='year', values='state_support_share', aggfunc='mean').plot(kind='bar'))
display(data.pivot_table(index='year', values='state_support_share', aggfunc='mean')['state_support_share'].mean())
# Out:
#       state_support_share
# year
# 2013                 0.47
# 2014                 0.55
# 2015                 0.56
# 2016                 0.57
# 2017                 0.51
# 2018                 0.54
# 2019                 0.51
# <AxesSubplot:xlabel='year'>
# 0.5314577479500034

# %% [markdown]
# Для фильмов с государственной поддержкой доля такой поддрежки в общем бюдете фильма составляет в среднем 53%, минимальное значение доли составляет 47% в 2013 году, макисмальное - 57% в 2016

# %% [markdown]
# - Также рассчитаем значение "окупаемости инвестиций" (rate of return или ROI)

# %%
data['rate_of_return'] = (data['box_office'] - data['budget']) / data['budget']

# %%
data.sort_values(by='state_support_share', ascending=False).head()
# Out:
#                        title  pu_number           show_start_date  \
# 2873       Помню - не помню!  111004916 2016-03-01 12:00:00+00:00
# 3046  Любовь с ограничениями  111008216 2016-04-29 12:00:00+00:00
# 6322                Баба Яга  114006518 2018-11-08 12:00:00+00:00
# 6822     Большое путешествие  114002419 2019-04-20 12:00:00+00:00
# 2531                 Бармен.  111009615 2015-05-26 12:00:00+00:00
#
#                 type                                film_studio  \
# 2873  Художественный                            ООО "КиноФирма"
# 3046  Художественный  АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
# 6322    Анимационный                   ООО "Арт Пикчерс Студия"
# 6822    Анимационный                  ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 2531  Художественный  АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
#
#      production_country               director  \
# 2873             Россия            В.Ровенский
# 3046             Россия                Д.Тюрин
# ...

# %% [markdown]
# #### Вывод по шагу 2.6
#
# Добавлены новые столбцы, содержащие значения:
# - ФИО режиссера, указанного первым в списке режиссеров
# - наименование жанра, указанного в списке жанров. Считается основным жанром произведения
# - доли государственной поддержки от общего бюджета фильма
# - окупаемость инвестиций - отношение разности общих сборов и общего бюджета к общему бюджету

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, все, что от нам требовали выполнено качественно. Двигаемся дальше!

# %% [markdown]
# ### Вывод по шагу 2
#
# 1) **Типы данных:**
# - замена show_start_date на дату
# - замена некорректных значений ratings на числа. Тип ratings стал float
#
# 2) **Дубликаты**:
# - в большинстве случаев наличие дуликатов объяснимо, например, буликаты наименований фильмов
# - дубликаты в номерах прокатных удостоверений оставлены без изменений, появление таких дубликатов скорее всего вызваны ошибкой ввода данных в реестр прокатных удостоверений
#
# 3) **Пропуски**:
# - в большинстве случаев наличие пропусков объяснимо (атрибуты, характеризующие бюджеты и сборы фильмов) - на данном шаге оставлено без изменений
# - не ясна природа пропусков в атрибутах genres и ratings, скорее всего ошибка выгрузки - пропуски в ratings на данном шаге оставлены без изменений
# - проведена земена пропусков production_country в ручную на "Россия", director, producer на служебное значение "Джон Доу делет видео", film_studio на служебное значение "Студия Джон Доу делает видео", genres на служебное значение "Прочие/Неопределено"
#
# 4) **Категориальные значения**
# - изучены основные особенности категориальных атрибутов и выявлены проблемы в значениях (в основном это различное написание одинаковых наименований, преечисления)
# - удалены лшние пробелы во всех категориальных значениях
#
# 5) **Количественные значения**:
# - проведена замена нулевых значений бюджетов фильмов, для которых указана государственная поддержка, на сумму возвратных и невозвратных средств
# - остальные значения оставлены без изменений
# - рассчитана средняя доля госдуарственной поддержки в общем бюджете фильмов  - 53%. Значение меняется год от года
#
# 6) **Добавлены новые столбцы**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Здорово, что ты не забыл написать вывод по всему шагу

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ### Динамика проката

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №0:</b> Не совсем понятен комментарий к заданию и на что необходимо обратить внимание. Выдача прокатного удостоверение равносильно "вышло в прокат". В исходных наборах данных нет атрибута "вышло в прокат"/"не вышло в прокат". Сведения о бюджете или сборах никак не отражают того факта, что произведение не находилось в прокате. Наличие прокатного удостоверения обязательно для публичных показов фильмов на территории РФ: <b>некоммерческих показов</b> в кинозалах (некоторые кинофестивали, киноклубы, премьеры), коммерческого проката в кинотеатрах, выпуска на физических носителях, показов фильма другими техническими способами.
#
# В соответствии с федеральным законом от 22.08.1996 N 126-ФЗ "О государственной поддержке кинематографии Российской Федерации":
#
# - прокат фильма - распространение фильма в любой форме и любыми способами;
#
# - показ фильма - публичная демонстрация фильма, осуществляемая в кинозале, по эфирному, кабельному, спутниковому телевидению и другими техническими способами.
#
# Т.е. у фильма, выходившего в прокате общие кассовые сборы могут составлять 0 руб. Также, прокатное удосторение необходимо получить, например, на произведения, находящиеся в общественном достоянии - дата выпуска которых более 70 лет назад.
#
# Отмечу также, что в задании подразумевается, что show_start_date - дата премьеры фильма, а не дата выдачи прокатного удостоверения. Так, например, show_start_date или дата премьеры фильма "Особо важное задание" (строка №1) 13.09.2016, что не может быть правдой, т.к. фильм вышел на экраны в 1980 году.
#
# В исходном реестре Минкульутры дата выдачи ПУ = дате начала показа фильма в соответствии с данным ПУ и установленными целями.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Услышал тебя, здорово, что ты так глубоко копаешь. Да, дейсвтительно, ты разложил по полочкам и я согласен, что задание сформулирвано не достаточно точно. Мы с этим разберемся

# %% [markdown]
# На одной гистограмме покажем динамику в разрезе годов количиества выданых ПУ и количества ПУ фильмов со сборами выше 0, т.е. тех, что выходили "в прокате" в терминологии задания (добавим также динамику выдачи ПУ фильмов с гос.поддержкой)

# %%
data['year'].hist(bins=20)
data.query('box_office >= 0')['year'].hist(bins=20)
data.query('state_support >= 0')['year'].hist(bins=15)
plt.xlabel('год')
plt.ylabel('Кол-во ПУ')
plt.legend(['Всего ПУ', 'ПУ фильмов со сборами > 0', 'ПУ фильмов с гос. поддержкой'])
plt.show()
print('Доля фильмов, вышедших в прокат:', round((len(data.query('box_office >= 0')) / len(data))*100,1),'%')
# Out:
# Доля фильмов, вышедших в прокат: 42.2 %

# %%
movie_counter = data.pivot_table(index='year', values='pu_number', aggfunc='count')
movie_counter['box_exist'] = data.query('box_office >= 0').groupby('year')['pu_number'].count()
movie_counter.columns = ['count', 'box_exist']
movie_counter['box_exist'] = movie_counter['box_exist'].fillna(0)
movie_counter['box_exist_share'] = 100 * movie_counter['box_exist'] / movie_counter['count']
display(movie_counter)
movie_counter.plot(y='box_exist_share', kind='bar');
plt.ylabel('%')
# Out:
#       count  box_exist  box_exist_share
# year
# 2010    985        105            10.66
# 2011    622        109            17.52
# 2012    593        128            21.59
# 2013    630        184            29.21
# 2014    806        279            34.62
# 2015    705        465            65.96
# 2016    818        526            64.30
# 2017    505        357            70.69
# 2018    891        475            53.31
# 2019    930        530            56.99
# Text(0, 0.5, '%')

# %% [markdown]
# Динамика выдачи ПУ не равномерна и меняется год от года. Наибольшее количество прокатных удостоверений выдано в 2010 году, наименьшее в 2017 году. При этом в 2017 году в прокат вышла наибольшая доля фильмов получивших прокатные удостоверения (70%).
#
# Динамика выдачи ПУ фильмам, которые вышли в прокате (сборы более 0 руб.) - положительная с небольшим падением в 2017-2018 гг.
# Динамика доли прокатных фильмов от общего количество фильмов, получивших прокатные удостоверения, росла до 2017 года с 10 до 70%, в 2018-2019 гг. зафикисировано снижение доли таких фильмов до 53-56%.
#
# Т.о. количество фильмов, получающих прокатные удостоверения и имеющие сборы отличные от 0, ежегодно растет, кроме периода 2017-2018 гг.
#
# Отчетливо видно, что фильмы с государственной поддержкой - малая часть от всех фильмов, получивших прокатные удостоверения

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все сделано хорошо, молодец!

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №0:</b> Считаю не совсем корректной постановку задачи. В исходных наборах данных представлены сведения о сборах в разрезе фильма, т.е общий объем сборов фильма в рамках проката с момента выдачи прокатного удостоверения -  накопленный итог.
#
# В наборе не представлена информация о динамике сборов кажого фильма, который выходил в прокате, в разрезе годов, поэтому корректно рассчитать динамику проката по годам не представляется возможным.
#
# На данных набора мы можем показать только суммарные сборы всех фильмов в разрезе годов выхода, т.е.:
# - общие сборы фильмов, получившие ПУ в 2010 году - Х руб.
# - общие сборы фильмов, получившие ПУ в 2011 году - Y руб.
#
# Можно предложить следующий подход: создать дополнительные столбцы сборы 2010-2019, в которых будут хранится одинаковые значения сборов каждого фильма в конкретный год box_office_year_№ = суммарные сборы фильма / количество лет в прокате = box_office фильма / (2019- year + 1). Допущение: за каждый год проката у фильма были одинаковые сборы и каждый фильм был в прокате до 2019 года. За счет того, что есть динамика количеств выданных ПУ по годам, можно будет приблизительно получить и динамику сборов.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, мы и имели ввиду просмотр суммарных сборов по годам.

# %%
data_money = data.groupby('year')['box_office'].sum()
data_money.plot(kind='bar', figsize=(10,5), logy=True) #отобразим на логарифмической шкале
plt.xlabel('Год выпуска фильма')
plt.ylabel('Общие сборы, руб.')
plt.title('Общие сборы фильмов в разрезе года выдачи прокатного удостоверения');
display(data.groupby('year')['box_office'].sum())
# Out:
# year
# 2010        2,428,654.00
# 2011       14,102,765.00
# 2012        6,955,423.00
# 2013       29,799,706.20
# 2014    7,444,951,859.20
# 2015   39,497,365,196.40
# 2016   47,866,299,741.91
# 2017   48,563,707,217.51
# 2018   49,668,403,134.32
# 2019   48,425,708,779.59
# Name: box_office, dtype: float64

# %% [markdown]
# Минимальные сборы в 2010 году составили 2,4 млн руб., максимальные в 2016-2019 47-49 млрд руб. Резкий рост пришелся на 2014 год. Связано это с тем, что в 2014 году были введены прокатные удостоверения и установлен штраф за показ произведений без ПУ. И для показа популярных фильмов в сетях кинотетров стало необходимым иметь ПУ.
#
# В целом в дальнейшем весь анализ объемов сборов целесообранее проводить с 2015 по 2019 гг.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Отлично, молодец!

# %% [markdown]
# ###  Средние и медианные сборы

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %% [markdown]
# Рассмотрим 2 случая для сравдения.
#
# 1) Набор mkrf_shows содержит все известные данные о сборах всех фильмов. Т.е. для фильмов, которых нет в данном наборе, сведения о сборах отсутствуют, т.е. ряд значений box_office = NaN
#
# 2) Набор mkrf_shows содержит только те сведения о сборах, которые не нулевые (зачем хранить лишние 0?). Те сведения, которые были 0 - ошибки (а их всего 24 штуки на весь набор), поэтому у всех фильмов, которые не входят в mkrf_shows сборы нулевые.
#
# Дело в том, что в зависимости от подхода будет существенно различаться значения среднего и медианы.

# %% [markdown]
# 1) Случай №1. Стандартный, исследуемый в рамках работы

# %%
data_case_1 = data.pivot_table(index='year', values='box_office', aggfunc=['count','mean', 'median'])
display(data_case_1)
display(data_case_1['mean'].max() / data_case_1['median'].max())
data_case_1.plot(y='mean', kind='bar', figsize=(10,5), logy=True)
data_case_1.plot(y='median', kind='bar', figsize=(10,5), logy=True);
# Out:
#           count           mean       median
#      box_office     box_office   box_office
# year
# 2010        105      23,130.04     1,700.00
# 2011        109     129,383.17     3,000.00
# 2012        128      54,339.24     5,660.00
# 2013        184     161,954.92     3,522.50
# 2014        279  26,684,415.27    18,160.00
# 2015        465  84,940,570.31 4,920,933.00
# 2016        526  91,000,569.85 3,846,679.41
# 2017        357 136,032,793.33 9,968,340.00
# 2018        475 104,565,059.23 8,891,102.21
# 2019        530  91,369,261.85 4,627,798.34
# box_office   13.65
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, все верно)

# %% [markdown]
# 2) Случай №2. Все пропуски в box_office заменены на 0

# %%
data_box = data.loc[:, ['pu_number', 'year', 'box_office']]
data_box['box_office'] = data_box['box_office'].fillna(0)
data_case_2 = data_box.pivot_table(index='year', values='box_office', aggfunc=['count','mean', 'median'])
display(data_case_2)
display(data_case_2['mean'].max() / data_case_2['median'].max())
data_case_2.plot(y='mean', kind='bar', figsize=(10,5), logy=True)
data_case_2.plot(y='median', kind='bar', figsize=(10,5), logy=True);
# Out:
#           count          mean       median
#      box_office    box_office   box_office
# year
# 2010        985      2,465.64         0.00
# 2011        622     22,673.26         0.00
# 2012        593     11,729.21         0.00
# 2013        630     47,301.12         0.00
# 2014        806  9,236,912.98         0.00
# 2015        705 56,024,631.48   739,938.00
# 2016        818 58,516,258.85   479,832.50
# 2017        505 96,165,756.87 2,522,174.00
# 2018        891 55,744,560.20   289,040.00
# 2019        930 52,070,654.60   597,710.00
# box_office   38.13
# dtype: float64

# %%
data_case_all = pd.merge(data_case_1, data_case_2, on='year', how='outer')
data_case_all['mean_xy'] = data_case_all['mean_x'] / data_case_all['mean_y']
data_case_all['median_xy'] = data_case_all['median_x'] / data_case_all['median_y']
data_case_all
# Out:
#         count_x         mean_x     median_x    count_y        mean_y  \
#      box_office     box_office   box_office box_office    box_office
# year
# 2010        105      23,130.04     1,700.00        985      2,465.64
# 2011        109     129,383.17     3,000.00        622     22,673.26
# 2012        128      54,339.24     5,660.00        593     11,729.21
# 2013        184     161,954.92     3,522.50        630     47,301.12
# 2014        279  26,684,415.27    18,160.00        806  9,236,912.98
# 2015        465  84,940,570.31 4,920,933.00        705 56,024,631.48
# 2016        526  91,000,569.85 3,846,679.41        818 58,516,258.85
# 2017        357 136,032,793.33 9,968,340.00        505 96,165,756.87
# 2018        475 104,565,059.23 8,891,102.21        891 55,744,560.20
# 2019        530  91,369,261.85 4,627,798.34        930 52,070,654.60
#
#          median_y mean_xy median_xy
#        box_office
# year
# 2010         0.00    9.38       inf
# ...

# %% [markdown]
# **1) Случай №1**
#
# Наибольшие медианные и средние сборы выявляены в период 2017-2018 гг. В 2017 году  - 9,9 млн и 136 млн соответственно. Причем максимальное среднее больше максимальной медианы в 2017 году в 13,7 раз.
#
# **2) Случай №2**
#
# Наибольшие медианные и средние сборы также выявляены в  2017 г. 2,5 млн и 96 млн соответственно. Максимальное среднее больше максимальной медианы в 2017 году в 38 раз.
#
# **Различия**
#
# Различия между средними и медианными значениями в 2-х случаях существенные. Между средними примерно 1,4-2,9 раза в период 2014-2019 гг. Между медаианными значениями - 4-30 раз в аналогичный период. **Т.о. результат может сильно зависить от способа подсчета и понимания поставленной задачи.**
#
# В 2017 году было выдано наименьшее количество прокатных удостверений, но получается, что эти прокатные удостоверения были выданы одним из самых прибыльных фильмов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ты использовал интересную методику. Скажу, что мне ближе второй вариант, нам был необходим первый и он вычислен правильно

# %% [markdown]
# ### Возрастные ограничения

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %%
data_age_restriction = pd.DataFrame(data.query('year >= 2015').pivot_table(
           index='age_restriction', columns='year',values='box_office', 
           aggfunc='sum')).reset_index()
data_age_restriction.columns = ['age_restriction', '2015', '2016', '2017', '2018', '2019']
data_age_restriction['total'] = pd.DataFrame(data.query('year >= 2015').groupby(
                                             'age_restriction')['box_office'].sum().reset_index())['box_office']
display(data_age_restriction)

plt.figure(figsize=(20,10))
sns.barplot(x='year', y='box_office', hue='age_restriction', data=data.query('year >= 2015'), estimator=sum, palette='rocket', ci=None);
plt.xlabel('Год')
plt.ylabel('Сборы руб.');
# Out:
#                           age_restriction              2015              2016  \
# 0  «0+» - для любой зрительской аудитории    379,054,578.37    150,228,848.67
# 1         «12+» - для детей старше 12 лет 13,616,082,008.91 12,204,446,524.39
# 2         «16+» - для детей старше 16 лет 11,368,120,870.27 16,664,548,541.74
# 3             «18+» - запрещено для детей  5,432,308,367.44  6,793,929,818.87
# 4           «6+» - для детей старше 6 лет  8,701,799,371.41 12,053,146,008.24
#
#                2017              2018              2019             total
# 0    229,598,930.00     32,449,002.11     17,746,066.82    809,077,425.97
# 1  7,851,427,660.67 14,267,291,660.69 12,680,198,773.67 60,619,446,628.33
# 2 18,745,042,900.06 16,503,602,346.96 12,753,418,984.60 76,034,733,643.63
# 3  9,651,495,581.02  8,760,085,501.15 10,121,796,303.64 40,759,615,572.12
# 4 12,086,142,145.76 10,104,974,623.41 12,852,548,650.86 55,798,610,799.68

# %%
pd.DataFrame(data.query('year >= 2015').pivot_table(
           index='age_restriction', columns='year',values='pu_number', 
           aggfunc='count')).reset_index()
# Out:
# year                         age_restriction  2015  2016  2017  2018  2019
# 0     «0+» - для любой зрительской аудитории    50    73    44    77    73
# 1            «12+» - для детей старше 12 лет   137   136    70   243   203
# 2            «16+» - для детей старше 16 лет   249   269   153   235   266
# 3                «18+» - запрещено для детей   192   245   172   222   255
# 4              «6+» - для детей старше 6 лет    77    95    66   114   133

# %% [markdown]
# Наибольшие сборы выявлены у продукции категории "16+" и "12+", наименьшие - у "0+". В период 2015-2017 растут сборы у фильмов категории "16+" и "18+", падают - у категории "12+". В 2018-2019 гг. заметен тренд роста сборов фильмов категории "12+" и "18+" и падение сборов у фильмов "16+".
#
# Сборы категорий "12+" и "16+" находятся в некой "противофазе". По большому счёту это не связано с изменением числа выпускаемых фильмов в различных категориях (число всех фильмов резко сократилось, но сборы максимальные), а с тем, что посетили кинотеатров также растут, и 16-ти летние из 2016 года в 2018 году уже могут посещать сеансы фильмов "18+". Послетителей из категории "12+" в массе своей больше и ежегодно они дают прирост в категории "16+" (поэтому и наблюдается падение сборов фильмой данной категроии в 2015-2017 гг).
#
# Также рост в отдельных категориях объясняется тем, что по мере взросления посетители кинотеатров становятся более платежеспособными, также расте стоимость билетов (динамику курса и инвляцию никто не отменял)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Верно

# %% [markdown]
# ###  Жанр, тип, режиссер, страна

# %% [markdown]
# - Проведем анализ в иных разрезах: по основному жанру, по типу фильма, режиссеру

# %% [markdown]
# Создадим функцию, которая будет возвращать датафрейм в виде сводной таблицы, как в предыдущих пунктах, но немного видоизмененной  - топ-10 по характеристике.
#
# *Хотелось также функцию, которая бы сворачивала сводную таблицу обратно в горизонтальную, но пока обойдусь без неё просто методом melt (это что-то из Сабвея?)*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   pu_number              7485 non-null   int64
#  2   show_start_date        7485 non-null   datetime64[ns, UTC]
#  3   type                   7485 non-null   object
#  4   film_studio            7485 non-null   object
#  5   production_country     7485 non-null   object
#  6   director               7485 non-null   object
#  7   producer               7485 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   float64
# ...

# %%
def data_top10(feature):
    df = pd.DataFrame(data.query('year >= 2015').pivot_table(
               index=feature, columns='year', values='box_office', 
               aggfunc='sum')).reset_index()
    df.columns = [feature, '2015', '2016', '2017', '2018', '2019']
    df['total_2015_2019'] = pd.DataFrame(data.query('year >= 2015').groupby(feature)['box_office'].sum().reset_index())['box_office']
    df = df.sort_values(by='total_2015_2019', ascending=False).reset_index().fillna(0).head(10)
    return df

#def data_for_sns(feature):
#    df = pd.DataFrame(data.query('year >= 2015').pivot_table(
#               index=[feature, 'year'], values='box_office', 
#               aggfunc='sum')).reset_index()
#    df.columns = ['year', feature, 'box_office']
#    df = df.sort_values(by='box_office', ascending=False).reset_index().fillna(0)
#    return df

# %% [markdown]
# 1) Основной жанр
#
# Посмотрим на топ 10 и подготовим таблицу для создания красивой визуализации (*и поучимся заодно понимать параметры и задавать цвета seaborn*)

# %%
data_top10('genre_1')
# Out:
#    index              genre_1             2015              2016  \
# 0     26           фантастика 9,794,353,598.70 12,092,232,749.57
# 1     18           мультфильм 5,743,995,984.24  8,759,274,357.55
# 2      3               боевик 7,709,584,899.67  4,995,436,970.60
# 3     27              фэнтези 1,160,608,592.00  8,249,383,106.22
# 4     12              комедия 4,150,798,996.68  2,768,291,750.68
# 5     10                драма 2,612,422,135.86  4,523,586,749.89
# 6     25                ужасы 2,309,601,061.36  1,818,874,207.64
# 7      0  Прочие/Неопределено 1,354,693,894.73  2,062,366,056.15
# 8     24              триллер 1,207,365,733.42    869,067,654.60
# 9     23                спорт   321,467,927.10     19,393,384.34
#
#               2017              2018             2019   total_2015_2019
# 0 8,883,071,567.00 11,051,021,423.88 9,108,688,749.75 50,929,368,088.90
# 1 7,017,126,483.76  5,984,846,541.33 9,106,072,767.50 36,611,316,134.38
# ...

# %%
data_top10_unpivot = pd.melt(data_top10('genre_1'), id_vars='genre_1', value_vars=['2015', '2016', '2017', '2018', '2019'])

plt.figure(figsize=(20,10))
#sns.set_style("darkgrid")
sns.lineplot(x='variable', y='value', hue='genre_1', data=data_top10_unpivot, palette='rocket')
plt.title('Динамика сборов Топ-10 жанров')   
plt.xlabel('Год')
plt.ylabel('Сборы, руб');

# %% [markdown]
# Как видно из таблицы и графика каких-либо особенностей у популярных жанров нет. Самый популярный жанр всех времен и народов - фантастика (Мстители, кек). Остальные жанры менее популярны, но за второе место борятся жанры "мультфильм", "боевик", "комедия"

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, здесь все предсказуемо

# %% [markdown]
# 2) Тип фильма

# %%
data_top10('type')
# Out:
#    index                        type              2015              2016  \
# 0      5              Художественный 31,816,802,965.43 37,985,204,173.95
# 1      0                Анимационный  7,638,395,099.07  9,827,584,477.30
# 2      4                      Прочие     41,813,193.40     43,390,452.08
# 3      1              Документальный        353,938.50      9,627,928.08
# 4      3           Научно-популярный              0.00        492,710.50
# 5      2  Музыкально-развлекательный              0.00              0.00
#
#                2017              2018              2019    total_2015_2019
# 0 40,178,634,594.75 42,855,938,116.83 38,008,090,573.80 190,844,670,424.76
# 1  8,351,287,507.76  6,758,626,565.14 10,268,808,371.75  42,844,702,021.02
# 2     32,360,597.00     42,612,802.55    110,668,702.12     270,845,747.15
# 3        621,753.00      8,559,089.30     34,264,829.42      53,427,538.30
# 4        802,765.00      2,666,560.50      2,459,667.50       6,421,703.50
# ...

# %%
data_top10_unpivot = pd.melt(data_top10('type'), id_vars='type', value_vars=['2015', '2016', '2017', '2018', '2019'])

plt.figure(figsize=(20,10))
#sns.set_style("darkgrid")
sns.lineplot(x='variable', y='value', hue='type', data=data_top10_unpivot, palette='rocket')
plt.title('Динамика сборов Топ-6 типов')   
plt.xlabel('Год')
plt.ylabel('Сборы, руб');

# %% [markdown]
# С типами фильмов все гораздо очевиднее. На документалки и научпоп никто не ходит (поэтому 35% россиян считает, что Солнце вращается вокруг Земли). Самый популярный типы фильмов - художественный и анимационный

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, здесь тоже все ясно

# %% [markdown]
# 3) Режиссер

# %%
data_top10('director_name')
# Out:
#    index director_name             2015             2016             2017  \
# 0   1347     К.Шипенко             0.00             0.00   752,679,777.00
# 1    907     Джо Руссо             0.00   955,507,415.00             0.00
# 2   1036   Дэвид Йейтс             0.00 1,930,811,770.60             0.00
# 3   1445     Крис Рено             0.00 1,971,590,699.00             0.00
# 4    845    Джеймс Ван 1,486,131,019.00   272,871,725.20             0.00
# 5   1352    Кайл Балда 1,646,580,645.70             0.00 1,390,392,637.00
# 6    128  А.Мегердичев             0.00             0.00 2,779,686,144.00
# 7   1245     И.Куликов             0.00             0.00             0.00
# 8   1044    Дэвид Литч             0.00             0.00   195,110,029.00
# 9    734    Д.Дьяченко   294,590,750.60   270,538,437.90 1,655,037,688.00
#
#               2018             2019  total_2015_2019
# 0             0.00 3,453,522,949.35 4,206,202,726.35
# ...

# %%
data.query('director_name == "К.Шипенко"')
# Out:
#                  title  pu_number           show_start_date            type  \
# 2268  Исповедь Z@drota  111014214 2014-10-15 12:00:00+00:00  Художественный
# 2291    Любит не любит  111014614 2014-10-22 12:00:00+00:00  Художественный
# 4431            Кто Я?  111009810 2010-10-29 12:00:00+00:00  Художественный
# 5501           Салют-7  111006917 2017-10-01 12:00:00+00:00  Художественный
# 7226             Текст  111015619 2019-09-14 12:00:00+00:00  Художественный
# 7455             Холоп  111021719 2019-12-19 12:00:00+00:00  Художественный
#
#                                             film_studio production_country  \
# 2268             ООО "Магнум-фильм" по заказу ООО "ММЕ"             Россия
# 2291                            ООО "Патриот Продакшнс"             Россия
# 4431                                   ЗАО "Вайт Медиа"             Россия
# 5501                           ООО "Лемон Филмз Студио"             Россия
# ...

# %% [markdown]
# Наш передовик!

# %% [markdown]
#   В топ-10 режиисеров по кассовым сборам вошли 3 отечественных режиссера

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> А вот здесь неожиданно)

# %% [markdown]
# 4) Страна

# %%
data_top10('production_country')
# Out:
#    index    production_country              2015              2016  \
# 0    382                   США 26,240,707,273.41 28,040,704,220.55
# 1    333                Россия  6,469,869,350.78  7,401,538,671.68
# 2    390  США - Великобритания    781,627,030.20  1,617,903,339.65
# 3    420          США - Канада    294,842,966.00  1,588,710,677.00
# 4    418             США - КНР              0.00    191,082,889.40
# 5    502               Франция    471,059,643.30    189,769,135.66
# 6     74  Великобритания - США     22,343,626.00     81,295,980.02
# 7    383       США - Австралия    806,223,942.11     57,852,660.18
# 8    466  США, Франция, Япония              0.00              0.00
# 9    416         США - Испания              0.00              0.00
#
#                2017              2018              2019    total_2015_2019
# 0 27,999,856,199.06 24,338,949,327.08 22,446,341,563.85 129,066,558,583.95
# 1 11,333,222,524.42 13,476,745,057.37 10,603,487,437.01  49,284,863,041.26
# ...

# %%
data_top10_unpivot = pd.melt(data_top10('production_country'), id_vars='production_country', value_vars=['2015', '2016', '2017', '2018', '2019'])

plt.figure(figsize=(20,10))
#sns.set_style("darkgrid")
sns.lineplot(x='variable', y='value', hue='production_country', data=data_top10_unpivot, palette='rocket')
plt.title('Динамика сборов Топ-10 стран')   
plt.xlabel('Год')
plt.ylabel('Сборы, руб');

# %% [markdown]
# Как видно, наибольщие сборы у фильмов производства США и России. С учетом того, что в остальном топ-10 стран-производителей США является страной учатсницей производства, суммарные сборы фильмов из США будут еще выше. По графику также видно, что сборы отечественных фильмов постепенно растут.
#
# Попробуем выделить из столбца со странами-производителями первые значения страны, видоизменив функцию выделения первого значения

# %%
def create_state_column(column):
    if ',' in str(column):
        split_column = str(column).split(',')
        column = split_column[0]
    elif ', ' in str(column):
        split_column = str(column).split(', ')
        column = split_column[0]
    elif ' , ' in str(column):
        split_column = str(column).split(' , ')
        column = split_column[0]
    elif ' ,' in str(column):
        split_column = str(column).split(' ,')
        column = split_column[0]
    elif ' - ' in str(column):
        split_column = str(column).split(' - ')
        column = split_column[0]
    elif '-' in str(column):
        split_column = str(column).split('-')
        column = split_column[0]
    elif ' -' in str(column):
        split_column = str(column).split(' -')
        column = split_column[0] 
    elif '- ' in str(column):
        split_column = str(column).split('- ')
        column = split_column[0]
    return column

#в процессе дальнейшего анализа выяснилось, что в некоторых случаях разделителем
#может выступать пробел, но его так в функции использовтаь нельзя, т.к. пропадут наименования стран, состоящих из 2 и более слов.
#также есть тсранное наименование страны, начинающееся на 2019. Подобные косяки можно обработать вручную

data['production_country_1'] = data['production_country'].apply(create_state_column)
data['production_country_1'] = data['production_country_1'].str.strip()
data['production_country_1'].unique()
# Out:
# array(['США', 'СССР', 'Франция', 'Германия', 'Великобритания',
#        'Чехословакия', 'Новая Зеландия', 'Канада', 'Россия', 'Гонконг',
#        'Ирландия', 'Чехия', 'Люксембург', 'Япония', 'Аргентина', 'Дания',
#        'Австрия', 'Италия', 'КНР', 'Швеция', 'Испания', 'Мексика',
#        'Бразилия', 'Чили', 'Австралия', 'Португалия', 'Исландия',
#        'Южная Корея', 'Бельгия', 'Украина', 'Франция-Великобритания',
#        'Босния и Герцеговина', 'Великобритания-Австралия', 'Норвегия',
#        'Швейцария', 'Греция', 'Норвения', 'Грузия', 'Финляндия',
#        'Израиль', 'Иран', 'Нидерланды', 'Республика Узбекистан', 'Турция',
#        'Сербия', 'Киргизия', 'Индия', 'Польша', 'Армения', 'ЮАР',
#        'Республика Беларусь', 'Румыния', 'Болгария', 'Индонезия',
#        'Таиланд', 'Малайзия', 'Азербайджан', 'Парагвай', 'Уругвай', 'СЩА',
#        'Хорватия', 'Венгрия', 'Эстония', 'Венесуэла', 'Македония',
#        'Республика Кипр', 'Перу', 'Китай', 'Княжество Андорра',
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента №0:</b> Наверно можно упростить функцию, сделав в её начале цикл, проходящий по списку разделителей, но не совсем понятно, что указывать в .split('разделитель'). Возможно так
#
# seplist = [',', ', ', ' , ', ' ,', '-', '- ', ' - ', ' -']
#
# def create_state_column(column):
#
#     for i in seplist:
#
#         if i in str(column):
#
#             split_column = str(column).split(i)
#
#             column = split_column[0]
#
#     return column
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хм.. Думаю, что пустил бы также

# %%
data_top10('production_country_1')
# Out:
#    index production_country_1              2015              2016  \
# 0     59                  США 30,470,037,045.91 38,180,253,705.04
# 1     56               Россия  6,925,216,494.59  7,459,285,214.84
# 2      9       Великобритания    637,957,268.95    363,793,870.31
# 3     69              Франция    678,886,148.66    718,486,320.72
# 4     26                  КНР     88,149,064.40    587,563,563.87
# 5     28               Канада     28,838,865.20     91,171,813.79
# 6     13             Германия    113,218,909.90    106,445,737.55
# 7     24              Испания     79,741,186.80     97,272,701.81
# 8      2            Австралия    100,238,088.30     24,484,070.27
# 9      6              Бельгия     62,932,138.30              0.00
#
#                2017              2018              2019    total_2015_2019
# 0 33,619,342,858.06 32,783,703,760.94 31,237,711,307.25 166,291,048,677.20
# 1 11,434,277,601.44 13,510,416,786.63 11,301,425,229.55  50,630,621,327.05
# ...

# %%
data_top10_unpivot
# Out:
#       production_country variable             value
# 0                    США     2015 26,240,707,273.41
# 1                 Россия     2015  6,469,869,350.78
# 2   США - Великобритания     2015    781,627,030.20
# 3           США - Канада     2015    294,842,966.00
# 4              США - КНР     2015              0.00
# 5                Франция     2015    471,059,643.30
# 6   Великобритания - США     2015     22,343,626.00
# 7        США - Австралия     2015    806,223,942.11
# 8   США, Франция, Япония     2015              0.00
# 9          США - Испания     2015              0.00
# 10                   США     2016 28,040,704,220.55
# 11                Россия     2016  7,401,538,671.68
# 12  США - Великобритания     2016  1,617,903,339.65
# 13          США - Канада     2016  1,588,710,677.00
# 14             США - КНР     2016    191,082,889.40
# 15               Франция     2016    189,769,135.66
# 16  Великобритания - США     2016     81,295,980.02
# ...

# %%
data_top10_unpivot = pd.melt(data_top10('production_country_1'), id_vars='production_country_1', value_vars=['2015', '2016', '2017', '2018', '2019'])

plt.figure(figsize=(20,10))
#sns.set_style("darkgrid")
sns.lineplot(x='variable', y='value', hue='production_country_1', data=data_top10_unpivot, palette='rocket')
plt.title('Динамика сборов Топ-10 стран')   
plt.xlabel('Год')
plt.ylabel('Сборы, руб');

# %% [markdown]
# Получилась более достоверная динамика сборов в зависимости от страны производителя. Так суммарные сборы фильмов из США увеличились на 37 млрд, и заметен более резкий тренд на снижение сборов фильмов из США после  2016 года.
#
# Отдельно стоит отметить китайское кино, если в 2015 году сборы китайских фильмов составляли 88 млн, то в 2019 - 558.
#
# Российские зрители кроме фильмов из России и США также охотно посещают сеансы европейского кино

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, здорово, что ты провел такие манипуляции. В плане результата все более-менее ожидаемо и сходится с дейсвтиетльностью

# %% [markdown]
# ### ROI, ROR или "окупаемость вложенных средств"

# %% [markdown]
# В нашем случае под окупаемостью вложенных средств понимается отношение разницы сборов и бюджета фильма
#
# Исходя из общего смысла данного финансового показателя, если:
#
# - показатель > 1 - бюджет фильма (вложенные средства) полностью окупился и была получена прибыль
# - показатель = 1 - бюджет фильма (вложенные средства) полностью окупился, без убытков и прибыли
# - показатель < 1 - вложения не окупились
# - показатель = 0 - вложения не окупились, сборы равны вложенным средствам
# - показатель < 0 - провал

# %%
#data.plot(x='year', y='rate_of_return', kind='scatter', grid=True)
#data.plot(x='year', y='rate_of_return', kind='hexbin', grid=True, ylim=(-1,10))
plt.figure(figsize=(20,10))
sns.violinplot(x='year', y='rate_of_return', data=data.query('year >= 2015'), palette="Set3", bw=.2, cut=1, linewidth=2);
#sns.despine(left=True, bottom=True)

# %%
data['rate_of_return'].hist(bins=100);

# %%
display(data.query('rate_of_return > 1 and year >= 2015').groupby('year')['pu_number'].count().plot(kind='bar'))
plt.title('Количество фильмов с ROI (ROR) > 1');
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data.query('rate_of_return <= 1 and rate_of_return > 0 and year >= 2015').groupby('year')['pu_number'].count().plot(kind='bar')
plt.title('Количество фильмов с ROI (ROR) (0;1]');

# %%
data.query('rate_of_return <= 0 and year >= 2015').groupby('year')['pu_number'].count().plot(kind='bar')
plt.title('Количество фильмов с ROI (ROR) < 0');

# %%
data.query('rate_of_return <= 0 and year >= 2015').groupby('year')['pu_number'].count()
# Out:
# year
# 2015    67
# 2016    48
# 2017    24
# 2018    36
# 2019    49
# Name: pu_number, dtype: int64

# %%
data.query('rate_of_return > 0 and year >= 2015').groupby('year')['pu_number'].count()
# Out:
# year
# 2015    18
# 2016    12
# 2017    15
# 2018    20
# 2019    11
# Name: pu_number, dtype: int64

# %% [markdown]
# Уже по "скрипочной" диарамме видно, что количество фильмов с отрицательным ROI гораздо больше (правда, параметр подкручен немного). Т.е. "провальных фильмов больше, чем окупившихся или фильмов без прибыли. В 2010 году 67 против 18. Гораздо лучше показатели в 2017-2018 гг., когда провальных фильмов стало значительно меньше (24 и 36 шт.)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хм, интересно. Еще раз отмечу. что ты проводишь отличную работу!

# %% [markdown]
# ### Рейтинг фильмов

# %% [markdown]
# Ежегодно средний рейтинг фильмов падает, в 2018-2019 гг. замечен небольшой рост. Средний рейтинг всех фильмов составляет 6,49, медианное значение 6.6, максимальное 9,9.

# %%
display(data['ratings'].describe())
data.groupby('year')['ratings'].mean().plot(style='o-', figsize=(10,5));
# Out:
# count   6,519.00
# mean        6.49
# std         1.11
# min         1.00
# 25%         5.90
# 50%         6.60
# 75%         7.20
# max         9.90
# Name: ratings, dtype: float64

# %% [markdown]
# Наивысшие оценки получали фильмы жанров нуар, аниме, музыка и вестерн. Наинизшие оценки - у фильмов для взрослых, в жанре реальное ТВ (что это? гонзо кино?) и ужасы

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Не знаю, не могу предположить

# %%
display(data.groupby('genre_1')['ratings'].mean().sort_values(ascending=False).head(10))
display(data.groupby('genre_1')['ratings'].mean().sort_values(ascending=False).tail(10))
# Out:
# genre_1
# фильм-нуар       7.60
# аниме            7.48
# музыка           7.37
# вестерн          7.30
# документальный   7.24
# спорт            7.14
# биография        7.01
# концерт          6.93
# мюзикл           6.90
# драма            6.77
# Name: ratings, dtype: float64
# genre_1
# Прочие/Неопределено   6.46
# история               6.43
# приключения           6.40
# мультфильм            6.27
# детский               6.11
# комедия               5.98
# семейный              5.95
# ужасы                 5.66
# реальное ТВ           5.60
# для взрослых          4.47
# Name: ratings, dtype: float64

# %% [markdown]
# В разрезе стран средний рейтинг выглядит не то, что бы странно, но странно. Самые высокие средние рейтинги у фильмов не из топ-стран производителей. Скорее всего это вызвано тем, что у топ-стран по кол-ву выпущенных виьмов достаточно большой разброс значенй рейтингов и усредненное значение, так же как и медианное, стремятся к среднему и медианному всего набора.
#
# Также видно, что супер-мега-функция по выделению первой страны из списка стран не сработала. Возможно, в "США -Великобритания" разделитель не дефис, а другой символ, но очень похожий.

# %%
display(data.groupby('production_country_1')['ratings'].mean().sort_values(ascending=False).head(10))
display(data.groupby('production_country_1')['ratings'].mean().sort_values(ascending=False).tail(10))
# Out:
# production_country_1
# Ливан                 8.20
# США -Великобритания   8.00
# Чехословакия          7.70
# 2019                  7.40
# Голландия             7.40
# Республика Беларусь   7.32
# Македония             7.30
# Иран                  7.27
# Киргизия              7.25
# Новая Зеландия        7.13
# Name: ratings, dtype: float64
# production_country_1
# Малайзия                5.18
# Латвия                  5.15
# Перу                    4.65
# Литва                   4.45
# Республика Казахстан    4.40
# Азербайджан             1.10
# Кения                    NaN
# Монголия                 NaN
# Республика Армения       NaN
# Республика Узбекистан    NaN
# Name: ratings, dtype: float64

# %% [markdown]
# Рейтинги отечественных фильмов с 2010 года были ниже рейтингов фильмов из США, но в 2017-2019 гг. средние рейтинги фильмов из России и США сравнялись (в России начали лучше снимать? Боты накрутили... ха-ха-ха не смешите мо....да, да, товарищ майор, стали лучше снимать)

# %%
display(data.query('production_country_1 == "США"').groupby('year')['ratings'].mean().plot(style='o-', figsize=(10,5)))
display(data.query('production_country_1 == "Россия"').groupby('year')['ratings'].mean().plot(style='x-', figsize=(10,5)))
# Out:
# <AxesSubplot:xlabel='year'>
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### Вывод по шагу 3
#
# 1) В среднем доля фильмов, вышедших в прокат составляет 42.2% (доля фильмов получивших сборы более 0 руб.), меняется от года к году. Наибольшая доля фильмов вышедших в прокат выявлена в 2017 году (70%). ТАкже в этом году зафикисрованы наибольшие значения среднего и медианного значения сборов - 136 млн и 9,9 млн соответственно. В период 2016-2019 гг. общие сборы составили в среднем 48 млрд руб.
#
# 2) Динамика сборов зависит от возрастной категории фильма, самые популярные фильмы - фильмы категории 16+, в тоже время заметен переток со временем сборов из категории в категорию, т.к. растет посетитель кинотеатров
#
# 3) Какой-либо явной динамики среди жанров нет. Есть самые популярные жанры - фантастика (топ-топов), мультфильм, боевик.
#
# 4) Самые невостребованные типы фильмов с точки зрения сборов - документальные и научно-популярные - для искушенной публики.
#
# 5) Среди самых "кассовых" режиссеров есть 3 отечественных режиссера
#
# 6) с 2015 года растут общие сборы отечественных фильмов. Фильмы из России одни из самых "кассовых" после фильмов из США
#
# 7) Большинство фильмов провалилось в прокате, общие сборы таких фильмов меньше вложенных средств
#
# 8) Средний рейтинг фильмов падал до 2017 года, но после начал опять расти, хоть и не достиг свох максимальных средних значений. Средний рейтинг отечественных фильмов ежегодно растет и в 2018 году сравнялся со средний рейтингом фильмов из США

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Была проведена большая работа, мы получили интересные и практически применимые выводы.

# %% [markdown]
# ## Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# ### Объемы государственной поддержки

# %% [markdown]
# Рассмотрим отдельно только те фильмы, которые оплучили гос. поддержку - те фильмы, для которых значения атрибутов refundable_support и nonrefundable_support не NaN

# %%
support_movies = data.query('state_support >= 0')

# %%
display(support_movies.groupby('year')[['refundable_support', 'nonrefundable_support', 'state_support']].agg('mean'))
display(support_movies.groupby('year')[['refundable_support', 'nonrefundable_support', 'state_support']].agg('sum').plot(kind='bar', figsize=(10,5)))
display(support_movies.groupby('year')[['refundable_support', 'nonrefundable_support', 'state_support']].agg('sum').plot(kind='area', figsize=(10,5)))
plt.show()
# Out:
#       refundable_support  nonrefundable_support  state_support
# year
# 2013                0.00          67,173,972.50  67,173,972.50
# 2014        4,437,500.00          31,312,643.69  35,750,143.69
# 2015        7,408,757.20          35,105,678.37  42,514,435.57
# 2016       15,106,557.38          55,436,975.11  70,543,532.49
# 2017       17,545,045.88          60,112,799.54  77,657,845.41
# 2018       11,821,428.57          49,731,597.59  61,553,026.16
# 2019       13,257,142.86          56,800,000.00  70,057,142.86
# <AxesSubplot:xlabel='year'>
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# С 2013 года объем государственной поддрежки растет, наблюдается снижение гос.поддрежки в 2017-2018 гг., при этом среднее значение государственной поддержки в 2017 году является самым максимальным. Объем невозвратных средств растет пропорционально объему поджержки

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Интересно

# %%
#support_movies_unpivot = pd.melt(support_movies('year'), id_vars='genre_1', value_vars=['2015', '2016', '2017', '2018', '2019'])

# %%
support_movies_pivot_year = pd.DataFrame(support_movies.pivot_table(
                        index='year', values=['refundable_support', 'nonrefundable_support', 'state_support', 'budget', 'box_office'],
                        aggfunc={'refundable_support':'sum', 'nonrefundable_support':'sum', 'state_support':'sum', 'budget':'sum', 'box_office':'sum'}).reset_index())
support_movies_pivot_year['ref_share'] = support_movies_pivot_year['refundable_support'] / support_movies_pivot_year['state_support']
support_movies_pivot_year['nonref_share'] = support_movies_pivot_year['nonrefundable_support'] / support_movies_pivot_year['state_support']
support_movies_pivot_year.reset_index()
print(support_movies['pu_number'].count(), 'фильма получили поддержку на сумму', support_movies['state_support'].sum(), 'руб.' )
display(support_movies_pivot_year)
display(support_movies_pivot_year.plot(x='year', y=['ref_share', 'nonref_share'], style='o-', figsize=(10,5),legend=True))
# Out:
# 332 фильма получили поддержку на сумму 20200688312.0 руб.
#    year        box_office            budget  nonrefundable_support  \
# 0  2013     20,322,385.10    255,435,390.00         134,347,945.00
# 1  2014  1,017,422,166.60  1,302,484,783.00         501,002,299.00
# 2  2015  5,785,285,418.14  7,738,669,207.00       3,019,088,340.00
# 3  2016  6,081,707,839.10  7,554,942,748.00       3,381,655,482.00
# 4  2017 10,865,075,300.96  7,057,172,568.00       2,464,624,781.00
# 5  2018  9,934,069,010.25  7,000,664,099.00       2,784,969,465.00
# 6  2019  8,409,627,454.63 12,722,866,609.00       3,976,000,000.00
#
#    refundable_support    state_support  ref_share  nonref_share
# 0                0.00   134,347,945.00       0.00          1.00
# 1       71,000,000.00   572,002,299.00       0.12          0.88
# 2      637,153,119.00 3,656,241,459.00       0.17          0.83
# 3      921,500,000.00 4,303,155,482.00       0.21          0.79
# ...

# %%
support_movies.groupby('production_country_1')['pu_number'].count() #проверим, действительно ли российские фильмы получают гос. поддрежку
# Out:
# production_country_1
# Россия    332
# Name: pu_number, dtype: int64

# %% [markdown]
# Всего с 2013 года 332 российских фильма получили государственную поддрежку на сумму более 20 млрд руб.
# Как видим, ежегодно растет доля возвратных средств, выделенных на поддержку отечественного кинематографа и в 2018-2019 гг. составляла 19% (максимальное относительное значение 23% в 2017 г.). В абсолютных значениях маскимальный возвратный объйм средств был выделен в 2019 году на сумму 928 млн руб.

# %%
support_movies_pivot_year['support_budget_share'] = support_movies_pivot_year['state_support'] / support_movies_pivot_year['budget']
display(support_movies_pivot_year['support_budget_share'].mean())
display(support_movies_pivot_year.plot(x='year', y=['budget', 'state_support'], style='o-', figsize=(10,5),legend=True))
# Out:
# 0.4765939653247108
# <AxesSubplot:xlabel='year'>

# %%
display(support_movies_pivot_year.plot(x='year', y=['support_budget_share'], style='o-', figsize=(10,5),legend=True))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
support_movies_pivot_year
# Out:
#    year        box_office            budget  nonrefundable_support  \
# 0  2013     20,322,385.10    255,435,390.00         134,347,945.00
# 1  2014  1,017,422,166.60  1,302,484,783.00         501,002,299.00
# 2  2015  5,785,285,418.14  7,738,669,207.00       3,019,088,340.00
# 3  2016  6,081,707,839.10  7,554,942,748.00       3,381,655,482.00
# 4  2017 10,865,075,300.96  7,057,172,568.00       2,464,624,781.00
# 5  2018  9,934,069,010.25  7,000,664,099.00       2,784,969,465.00
# 6  2019  8,409,627,454.63 12,722,866,609.00       3,976,000,000.00
#
#    refundable_support    state_support  ref_share  nonref_share  \
# 0                0.00   134,347,945.00       0.00          1.00
# 1       71,000,000.00   572,002,299.00       0.12          0.88
# 2      637,153,119.00 3,656,241,459.00       0.17          0.83
# 3      921,500,000.00 4,303,155,482.00       0.21          0.79
# 4      719,346,881.00 3,183,971,662.00       0.23          0.77
# ...

# %% [markdown]
# В целом, объем государственной поддержки растет в соответствии с ростом общего бюджета (и аналогичным образом уменьшается). Средняя доля государственной поддержки в общем бюджете фильмов составляет 47%. Доля колеблется год от года, дотсигает пика в 2016 году (57%). Минимальное значение в 2019 году - 39%
#
# *Хозяйке на заметку: в целях привлечения внимания общества к российскому кинематографу решено провести в 2016 году в РФ Год российского кино в соответствии с указом Президента РФ  от 7 октября 2015 г. № 503 "О проведении в Российской Федерации Года российского кино"*
#
# Зависимости динамики объемов бюджетов, сборов, государственной поддрежки хорошо иллюстрируются значениями корреляций. Между данными величинами сильная положительная зависимость с коэфициентами от 0,78 до 0,98. Есть примеры и полной зависимости (коэф =1) - динамика общего объема государственной подрежки и динамика выделенных невозвратных средств.

# %%
display(support_movies_pivot_year.loc[:, {'box_office', 'budget', 'nonrefundable_support', 'refundable_support', 'state_support'}].corr())
display(sns.heatmap(support_movies_pivot_year.loc[:, {'box_office', 'budget', 'nonrefundable_support', 'refundable_support', 'state_support'}].corr()));
# Out:
#                        box_office  nonrefundable_support  refundable_support  \
# box_office                   1.00                   0.78                0.82
# nonrefundable_support        0.78                   1.00                0.98
# refundable_support           0.82                   0.98                1.00
# state_support                0.79                   1.00                0.99
# budget                       0.78                   0.97                0.93
#
#                        state_support  budget
# box_office                      0.79    0.78
# nonrefundable_support           1.00    0.97
# refundable_support              0.99    0.93
# state_support                   1.00    0.96
# budget                          0.96    1.00
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ожидаемо. Хорошо

# %% [markdown]
# Почти схожая картина и для отдельных произведений. Отдельные атрибуты имеют сильную зависимость между собой:
# - государственная поддержка и невозвратные средства
# - государснвенная поддержка и общий бюджет фильма.
# Т.е. чем больше бюджет фильма, тем больше государственной поддрежки данному фильму (что в целом понятно, но не так интуитивно, т.к. может быть такая ситуация, что гос.поддрежки больше, значит меньше частных ивестиций для сохранения первоначальных значений бюджета фильма), и, следовательно больший объем выделенных невозвратных средств.
#
# Практически никак не связаны между собой значения общего бюджета фильма, размеров госудасрвтенной поддержки и общих сборов. Динамики этих показателей по годам имеет сильную зависимость, но не по отдельности для каждого фильма. Т.е. большой бюджет и крупная гос.помощь не гарантируют успеха в прокате (привет, BadComedian)

# %%
display(support_movies.loc[:, {'box_office', 'budget', 'nonrefundable_support', 'refundable_support', 'state_support'}].corr())
display(sns.heatmap(support_movies.loc[:, {'box_office', 'budget', 'nonrefundable_support', 'refundable_support', 'state_support'}].corr()))
# Out:
#                        box_office  nonrefundable_support  refundable_support  \
# box_office                   1.00                   0.46                0.31
# nonrefundable_support        0.46                   1.00                0.36
# refundable_support           0.31                   0.36                1.00
# state_support                0.49                   0.95                0.64
# budget                       0.38                   0.62                0.65
#
#                        state_support  budget
# box_office                      0.49    0.38
# nonrefundable_support           0.95    0.62
# refundable_support              0.64    0.65
# state_support                   1.00    0.74
# budget                          0.74    1.00
# <AxesSubplot:>

# %% [markdown]
# ### Окупаемость

# %%
support_movies_pivot_year.plot(x='year', y=['budget', 'box_office'], style='o-', figsize=(10,5),legend=True)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# До 2016 года суммарные бюджеты фильмов с государственной поддрежкой были выше общих сборов. Ситуация изменилась в 2017-2018 гг. когда фильмы стали собирать больше затраченных на их производство средств. А шо по ROI?

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Интересно, с чем это связано. Неужели стали лучше снимать?

# %%
support_movies.groupby('year')['rate_of_return'].mean().plot(style='o-', figsize=(10,5),legend=True, grid=True);

# %% [markdown]
# Как видно из графика только в 2017 и 2018 гг. средний ROI всех отечественных филмов был выше 0. Т.е. сборы были чуть больше бюджета (затрат), но с точки зрения окупаемости - вложения не окупились, а в остальные годы общий средний ROI вообще отрицательный. Т.к. данные фильмы получили господдрежку, то можно сказать, что у фильмов низкая бюджетная эффективность (Минфин, куда ты смотришь? Но кино - социальная функция и обязанность государства, грех на нем зарабатывать)

# %% [markdown]
# Всего у 79 фильмов с гос поддержкой из 332 сборы были выше затрат и наибольшее количество таких фильмов вышло в прокат в 2015 и 2018 гг. (18 и 20 фильмов соответственно). При этом в эти же годы вышло максимальнео количество фильмов, не то что бюджет которых, а объем государственной поддержки больше общих сборов.

# %%
support_movies.query('box_office > budget').groupby('year')['pu_number'].count()
# Out:
# year
# 2014     3
# 2015    18
# 2016    12
# 2017    15
# 2018    20
# 2019    11
# Name: pu_number, dtype: int64

# %%
support_movies.query('state_support > box_office').groupby('year')['pu_number'].count()
# Out:
# year
# 2013     2
# 2014    11
# 2015    61
# 2016    40
# 2017    17
# 2018    30
# 2019    39
# Name: pu_number, dtype: int64

# %% [markdown]
# С точки зрения эффектвиности именно бюджетных (государственных) средств:

# %%
print('(сборы - гос.подержка) / гос.поддрежка =  :', 
      ((support_movies['box_office'].sum() - support_movies['state_support'].sum()) / support_movies['state_support'].sum())
      * 100, '%')
# Out:
# (сборы - гос.подержка) / гос.поддрежка =  : 108.47561689154386 %

# %% [markdown]
# Т.е в целом даже что-то "заработали", но если рассмотреть возвратные субсидии:

# %%
print('(сборы - возвр. субс.) / возвр. субс =  :', 
      ((support_movies['box_office'].sum() - support_movies['refundable_support'].sum()) / support_movies['refundable_support'].sum())
      * 100, '%')
# Out:
# (сборы - возвр. субс.) / возвр. субс =  : 969.1421572678344 %

# %% [markdown]
# то получается, что заработали еще как!
#
# **Т.е в общем случае, государству определенно выгодно обеспечивать отечественный кинематоргаф бюджетными средствами, в т.ч. в виде возвратных средств. Но стоит подумать над механизмом выделения бюджетных денег. Возможно, чтоит рассмотреть меры по выдаче кредитов по льготной ставке за счет гарантий государства.**
#
# Отдельно надо расчитать экономический мультипликативнй эффект от бюджетных вложений в сферу кинематографа с учетом других сфер (торговля, недвижимость, транспорт, общепит, ИТ (эффекты и пиу пиу кто-то же делает) на основе межотраслевого баланса.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, ты затрагиваешь правильные вопросы

# %% [markdown]
# Но сначала санкции и расстрелы не смотря на громкие имена и былые заслуги. Либо отлучение от профессии:

# %%
support_movies.query('refundable_support > box_office').groupby('director_name')['pu_number'].count()
# Out:
# director_name
# А.Аксененко                                 1
# А.Касаткин                                  1
# А.Котт                                      1
# А.Миндадзе                                  1
# А.Нужный                                    1
# А.Соколов                                   1
# А.Цицилин                                   1
# В.Бортко                                    1
# В.Сторожева                                 1
# В.Хотиненко                                 1
# Д.Суворов                                   1
# Е.Баранов                                   1
# Е.Невский (псевдоним Е.Торрес)              1
# И.Учитель                                   1
# И.Шахназаров                                1
# К.Белевич (псевдоним - Кирилл Астахов)      1
# К.Худяков                                   1
# Н.Бондарчук                                 1
# Н.Меркулова                                 1
# П.Руминов                                   1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Бондарчук попал, но не тот)))))))))

# %% [markdown]
# ### #Чёзафильм

# %% [markdown]
# Рассматривать отечетсвенное кино, получившее гос.поддрежку стоит только в разрезе рейтингов-жанров и бюджетов (было сделано выше). Разрезы режиссеров, студий и пр. будут не показательны, т.к. завтра Ф.Бондарчук снимет фильм за 100500 млрд господдрежки и весь наш анализ сломается
#
# Про "возврастную категорию". Лично моё мнение - это симулякр + 332 фильма для полноценного анализа недостаочно. Вывод будет примерно следующий: "самая непопулярная и не массовая по сборам категория - 0+, самая массовая 16+". Аналогичный результат в п 3.3.

# %% [markdown]
# #### Топы

# %% [markdown]
# Топ-10 отечественных фильмов по сборам

# %%
support_movies.sort_values(by='box_office', ascending=False).head(10)
# Out:
#                                 title  pu_number           show_start_date  \
# 7455                            Холоп  111021719 2019-12-19 12:00:00+00:00
# 5652                   Движение вверх  111011817 2017-12-21 12:00:00+00:00
# 6548                             Т-34  111024918 2018-12-21 12:00:00+00:00
# 5504               Последний богатырь  111007017 2017-10-19 12:00:00+00:00
# 5707                              Лёд  111000518 2018-02-01 12:00:00+00:00
# 2919                         Экипаж .  111005416 2016-03-21 12:00:00+00:00
# 3564                Притяжение (2016)  111018116 2016-12-16 12:00:00+00:00
# 5640                       Ёлки Новые  111011617 2017-12-21 12:00:00+00:00
# 5825                           Тренер  111003218 2018-04-19 12:00:00+00:00
# 5658  Три богатыря и принцесса Египта  114003317 2017-12-21 12:00:00+00:00
#
#                 type                                        film_studio  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Сходится с дейсвтительностью

# %% [markdown]
# У России три пути - танчики, спортсмены, богатыри

# %% [markdown]
# Топ-10 отечественных фильмов по бюджету

# %%
support_movies.sort_values(by='budget', ascending=False).head(10)
# Out:
#                      title  pu_number           show_start_date  \
# 7113  Тайна Печати Дракона  111012819 2019-09-12 12:00:00+00:00
# 5436              Матильда  111005717 2017-08-17 12:00:00+00:00
# 7463         Союз спасения  111022019 2019-12-26 12:00:00+00:00
# 7473             Вторжение  111022519 2019-12-23 12:00:00+00:00
# 7170                  Грех  111014419 2019-08-31 12:00:00+00:00
# 3350               Дуэлянт  111015416 2016-09-14 12:00:00+00:00
# 2919              Экипаж .  111005416 2016-03-21 12:00:00+00:00
# 5652        Движение вверх  111011817 2017-12-21 12:00:00+00:00
# 6548                  Т-34  111024918 2018-12-21 12:00:00+00:00
# 3254   Время первых (2017)  111001317 2017-02-21 12:00:00+00:00
#
#                 type                                        film_studio  \
# 7113  Художественный  ООО "Кинокомпания "СТВ"; ООО "РФГ Корп"; ООО "...
# 5436  Художественный                     ООО "ТПО "РОК", ООО "Матильда"
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> А вот здесь есть и незнакмые мне прежде)

# %% [markdown]
# Слышал, что в одном из фильмов "Рус, ну вы знаете Руса" инопланетян в баскетбол победили "за себя и за Сашку"

# %% [markdown]
# Топ-10 отечественных фильмов по гос.поддержке

# %%
support_movies.sort_values(by='state_support', ascending=False).head(10)
# Out:
#                      title  pu_number           show_start_date  \
# 7473             Вторжение  111022519 2019-12-23 12:00:00+00:00
# 7463         Союз спасения  111022019 2019-12-26 12:00:00+00:00
# 3350               Дуэлянт  111015416 2016-09-14 12:00:00+00:00
# 2919              Экипаж .  111005416 2016-03-21 12:00:00+00:00
# 5652        Движение вверх  111011817 2017-12-21 12:00:00+00:00
# 5568   Легенда о Коловрате  111007617 2017-11-30 12:00:00+00:00
# 3452               Ледокол  111016316 2016-10-11 12:00:00+00:00
# 5436              Матильда  111005717 2017-08-17 12:00:00+00:00
# 6886               Девятая  111007019 2019-09-19 12:00:00+00:00
# 7113  Тайна Печати Дракона  111012819 2019-09-12 12:00:00+00:00
#
#                 type                                        film_studio  \
# 7473  Художественный       ООО "Арт Пикчерс Студия", ООО "Водород 2011"
# 7463  Художественный                                ЗАО "Дирекция кино"
# ...

# %% [markdown]
# Честно говоря, к своему стыду не смотрел ни одного этого фильма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да уж, я тоже не смотрел :( может оно и к лучшему

# %% [markdown]
# _________________________________________________________________

# %% [markdown]
# Рассмотрим различные характеристики отечественного кино с государственной поддержкой

# %% [markdown]
# #### Рейтинг

# %% [markdown]
# В целом зависимость рейтинга от жанра:

# %%
support_movies.pivot_table(index='genre_1', values='ratings', aggfunc={'mean', 'median'}).sort_values(by='mean', ascending=False)
# Out:
#              mean  median
# genre_1
# криминал     7.50    7.80
# детский      7.12    7.25
# спорт        6.93    7.00
# биография    6.90    6.90
# детектив     6.76    6.80
# боевик       6.58    6.45
# мюзикл       6.55    6.60
# военный      6.47    6.40
# драма        6.42    6.40
# фантастика   6.15    6.20
# фэнтези      6.09    6.80
# мелодрама    5.95    6.20
# приключения  5.87    5.70
# мультфильм   5.80    6.20
# триллер      5.71    5.60
# реальное ТВ  5.60    5.60
# комедия      5.51    5.75
# семейный     5.41    4.80
# история      5.35    5.90
# ужасы        5.20    5.10

# %% [markdown]
# *Почему-то я не удивлен, но да ладно*
#
# Наивысшие оценки получают отечественные фильмы в жанрах "криминал", "детский" и "спорт". Это похоже на правду, потому что в России такое любят и умеют снимать. А вот с семейными фильмами и ужасами (как и в общем наборе) дела обстаят хуже.
#
# Например, стандартный диалог из семейного ужастика:
#
# -Она отказала мне. Сказала что любит тебя. Думает что любит тебя!
#
# -Да она не может любить меня!
#
# -Да я люблю тебяяяя!
#
# Страшно же!

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Сходится с моим ощущением дейсвтительности)

# %% [markdown]
# Зависимость рейтинга от жанра фильма, который "окупился"

# %%
support_movies.query('box_office > budget').pivot_table(index='genre_1', values='ratings', aggfunc={'mean', 'median'}).sort_values(by='mean', ascending=False)
# Out:
#              mean  median
# genre_1
# боевик       7.55    7.55
# биография    7.50    7.50
# приключения  7.50    7.50
# спорт        7.25    7.25
# драма        6.59    6.75
# военный      6.47    6.40
# история      6.40    6.40
# триллер      6.40    6.40
# мультфильм   6.01    6.25
# комедия      5.73    5.80
# семейный     5.50    5.00
# ужасы        5.27    5.10
# фантастика   5.25    5.25
# фэнтези      4.60    4.60

# %% [markdown]
# Распределение немного изменилось, но не сильно. Все же криминал у нас в прокате только по НТВ

# %% [markdown]
# Не вижу смысла рассматривать количественные характристики в разрезе "возрастных категорий" и "типов". По топ-10 видно, какая категоряи превалирует

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошо

# %% [markdown]
# #### Некие метрики

# %% [markdown]
# Посчитаем некоторые метрики, которые, возможно, о чём-то нам скажут (но это не точно). Сделаем небольшую модельку

# %% [markdown]
# 1) Создадим датафрейм с суммарными значениями денежных показателей и средним рейтингм в разрезе жанра

# %%
genre_support_rating = pd.DataFrame(support_movies.query('box_office > budget').pivot_table(index='genre_1', 
                    values={'box_office', 'budget', 'state_support','ratings'}, 
                    aggfunc={'box_office':'sum', 'budget':'sum', 'state_support':'sum', 'ratings':'mean'}).sort_values(
                    by='ratings', ascending=False).reset_index().dropna())
#genre_support_rating['rev_rub_rate'] = genre_support_rating['box_office'] / (genre_support_rating['ratings'] * 10)
#genre_support_rating['budg_rub_rate'] = genre_support_rating['budget'] / (genre_support_rating['ratings'] * 10)
#genre_support_rating['ssup_rub_rate'] = genre_support_rating['state_support'] / (genre_support_rating['ratings'] * 10)

#display(genre_support_rating.sort_values(by='rev_rub_rate'))
#display(genre_support_rating.sort_values(by='rev_rub_rate').plot(
#                    x='genre_1', y=['rev_rub_rate', 'budg_rub_rate', 'ssup_rub_rate'],
#                    kind='barh', figsize=(15,15), grid=True,))

# %% [markdown]
# 2) Создадим датафрейм с минимальными, максимальными и разницей макс и мин значенияй рейтинга в разрезе жанров

# %%
genre_rating = pd.DataFrame(support_movies.pivot_table(
               index='genre_1', values='ratings', aggfunc=['min','max']).reset_index())
genre_rating['delta'] = genre_rating['max'] - genre_rating['min']
genre_rating.columns = ['genre_1', 'min', 'max', 'delta']
#если вставить условие для отбора только тех фильмов, у которых сборы больше бюджета, то слишком много  NaN. 
#Оставим весь набор, нужна хоть какая-то динамика рейтинга

# %% [markdown]
# 3) Соединим таблицы, рассчитаем доп параметры. Выведем результат и диаграмму

# %%
merge_delta_table = genre_support_rating.merge(genre_rating, on="genre_1", how='left')

merge_delta_table['rev_rub_rate'] = merge_delta_table['box_office'] / (merge_delta_table['delta'] * 7)
merge_delta_table['budg_rub_rate'] = merge_delta_table['budget'] / (merge_delta_table['delta'] * 7)
merge_delta_table['ssup_rub_rate'] = merge_delta_table['state_support'] / (merge_delta_table['delta'] * 7)

display(merge_delta_table.sort_values(by='rev_rub_rate'))
display(merge_delta_table.sort_values(by='rev_rub_rate').plot(
                    x='genre_1', y=['rev_rub_rate', 'budg_rub_rate', 'ssup_rub_rate'],
                    kind='barh', figsize=(15,15), grid=True,))
display(merge_delta_table.sort_values(by='rev_rub_rate').plot(
                    x='genre_1', y=['rev_rub_rate', 'budg_rub_rate', 'ssup_rub_rate'],
                   figsize=(15,5), style='o-', grid=True,))
# Out:
#         genre_1        box_office           budget  ratings    state_support  \
# 13      фэнтези    100,874,704.69    42,000,000.00     4.60    28,000,000.00
# 10     семейный    549,935,546.65   397,922,287.00     5.50   241,000,000.00
# 11        ужасы    556,761,456.17   233,800,700.00     5.27   141,000,000.00
# 6       история    590,405,065.00   500,012,729.00     6.40   350,000,000.00
# 12   фантастика  1,242,479,906.05   450,067,392.00     5.25   390,000,000.00
# 2   приключения    544,332,260.00   528,441,977.00     7.50   250,000,000.00
# 0        боевик    504,223,082.64   230,000,000.00     7.55   115,000,000.00
# 7       триллер    578,000,720.43   199,551,503.00     6.40   135,000,000.00
# 1     биография    401,804,461.90   131,000,000.00     7.50    27,510,000.00
# 5       военный    916,458,225.04   533,884,000.00     6.47   140,000,000.00
# 8    мультфильм  4,331,902,164.92 2,061,265,049.00     6.01 1,065,000,000.00
# ...

# %% [markdown]
# **Теория следующая:**
#
# Для "жанра" (genres 1) плюс 1 балл в рейтинге КиноПоиска стоит:
# - дополнительных государственных вложений в год равных ssup_rub_rate
# - дополнительного общего бюджета в год равного budg_rub_rate
# - каждый новый + 1 балл в рейтинге принесет rev_rub_rate дополнительных сборов
#
# *Допущение: для всех жанров рейтинг растет 7 лет (2013-2019) с мин в 2013 до макс 2019 значения. Качество отечетсвенного кинематографа растет, все счастливы*
#
# *А на самом деле: части данных нет, минимум и максимум может быть зафикисрован в разные года. не в каждом жанре (в малой части) рейтинг не рос, а падал.*

# %% [markdown]
# **Таким образом получили:**
#
# - стоимость 1 балла на Кинопоиске в год в виде доп. гос.вложений в фильм в разрезе жанров
# - стоимость 1 балла на Кинопоиске в год в виде доп. бюджета фильма в разрезе жанров
# - профит от повышения на 1 балл в виде доп. сборов в год
#
# Как видно из графиков, что стоимость полуечения 1 балла на кинопоиске для гос.бюджета выше всего для филльмов в жанре "драма, спорт, комедия, мультфильм". Самый бюджетнонерентабельные жанры - фэнтези, семейный и ужасы.
#
# Вкладываемся в спортивные комедии, там бабло крутится
#
# Сдругой стороны, судя по тем же диаграммам, 0,5 руб. гос. вложений в жанр спорт на увеличение на 1 балл дадут 3,5 руб. дополнительных сборов.
#
# Т.е. 7:1 - не плохо. Вот вам и дополнительный мультипликативный эффект из сферы "развлечений". Кто такое считает?=)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хм, интересно. Интерсные метрики. Занимательные резульаты

# %% [markdown]
# ## Шаг 5. Напишите общий вывод

# %% [markdown]
# Внимательный читатель заметил, что очень часто повторяется ключевая дата. **Две  тысячи семнадцатый год**, *иногда 2016, а может и 2018, но это мелочи*
#
# Откроем Яндекс и погуглим (оксюморон)
#
# - Российский кинематограф установил в 2017 году рекорд кинопроката
# - С 2017 года в российских регионах действует система кинематографических ребейтов, когда местные администрации через специальные кинокомиссии возвращают продюсерам часть расходов на съемки в регионе (отели, питание, аренду транспорта и др.), а также помогают в получении разрешений на съемку, подборе локаций и прочем сопровождении.
# - Согласно документу, в целях привлечения внимания общества к российскому кинематографу решено провести в 2016 году в РФ Год российского кино
# - Минкультуры России, Фонд кино и представители крупнейших киносетей договорились увеличить в 2017 долю отечественных фильмов в прокате до 20%.
#
# Ну, вот ты и попался 2017 год.
#
# **Будем это иметь ввиду, чтобы дополнительно подкрепить фактурой наши выводы из исследования,** *преварительно напомнив, что не согласен с общей канвой задачи, когда суммарные сборы считаются в разрезе годов выдачи прокатных удостоверений и на основании этого строятся выводы. Считаю это неправильным и решительно протестую*
#
# **Результаты исследования**
#
# 1) Данные в наборах Минкуьтуры России осталвяют желать лучшего: есть одинаковые номера ПУ, нет единства в написании атрибутов с наименованими фильмов, режиссеров, студий, стран-поизводителей, продюссеров, типов фильмов. Есть проблемы в итоговых значениях бюджета фильма при наличии сведений о гос.финансировании (несовпадение сумм)
#
# 2) Общая картина:
#
# 2.1) Прокатные удостоверения:
#
#  - Динамика выдачи ПУ не равномерна и меняется год от года. Наибольшее количество прокатных удостоверений выдано в 2010 году, наименьшее в 2017 году. При этом в 2017 году в прокат вышла наибольшая доля фильмов получивших прокатные удостоверения (70%).
#
# 2.2) Сборы:
#
#  - Минимальные общие сборы составили 2,4 млн руб. в 2010 году, максимальные в 2016-2019 47-49 млрд руб. Резкий рост пришелся на 2014 год. Скорее всего это связано с тем, что в 2014 году были введены прокатные удостоверения и установлен штраф за показ произведений без ПУ. И для показа популярных фильмов в сетях кинотетров стало необходимым иметь ПУ.
# - Значения средних и медианных сборов для произведений зависит от понимания описания набора данных и приеняемого подхода. В работе было предложено 2 варианта рассчта (см. п. 3.2)
# - Наибольшие сборы выявлены у продукции категории "16+" и "12+", наименьшие - у "0+". В период 2015-2017 растут сборы у фильмов категории "16+" и "18+", падают - у категории "12+". В 2018-2019 гг. заметен тренд роста сборов фильмов категории "12+" и "18+" и падение сборов у фильмов "16+". По большому счёту это не связано с изменением числа выпускаемых фильмов в различных категориях (число всех фильмов резко сократилось, но сборы максимальные), а с тем, что посетили кинотеатров также растут, и 16-ти летние из 2016 года в 2018 году уже могут посещать сеансы фильмов "18+". Послетителей из категории "12+" в массе своей больше и ежегодно они дают прирост в категории "16+" (поэтому и наблюдается падение сборов фильмой данной категроии в 2015-2017 гг). Также рост в отдельных категориях объясняется тем, что по мере взросления посетители кинотеатров становятся более платежеспособными, также растет стоимость билетов (динамику курса и инвляцию никто не отменял)
# - Наибольшие сборы у фильмов производства США и России. Сборы отечественных фильмов постепенно растут, в то время как с 2016 года сборы в прокате фильмов из США падают. *Нунаконецто*
# -  Сточки зрения "эффективности вложений" большинство фильмов - с плохой окупаемостью, но динамика свидетельствует о том, что фильмов, у которых сборов меньше вложенного бюджета становится меньше
#
# 2.3) Популярность:
#
# - Самый популярный жанр (по сборам) - фантастика. На вторых местах  жанры "мультфильм", "боевик", "комедия"
# - Самый популярный тип фильмов - художественный и анимационный. На докуентальное кино и науч-поп спроса нет (пИчалька)
# - В топ-10 самых "кассовых" режиссеров вошли 3 российских режиссера. *Такими темпами догнать и перегнать можно*
# - Российские зрители кроме фильмов из России и США также охотно посещают сеансы европейского кино, а также смотрят китайские фильмы. Сборы таких фильмов растут ежегодно. *Так куда разворот? На Восток или на Запад*
#
# 2.4) Рейтинг:
#
# - Ежегодно средний рейтинг фильмов падает, в 2018-2019 гг. замечен небольшой рост. Средний рейтинг всех фильмов составляет 6,49.Наивысшие оценки получали фильмы жанров нуар, аниме, музыка и вестерн. Наинизшие оценки - фильмы для взрослых, в жанре реальное ТВ и ужасы
# - Рейтинги отечественных фильмов с 2010 года были ниже рейтингов фильмов из США, но в 2017-2019 гг. средние рейтинги фильмов из России и США сравнялись
#
# 2.5) Государственная поддержка отечественного кинематографа:
# - С 2013 года объем государственной поддрежки растет, наблюдается снижение гос.поддрежки в 2017-2018 гг., при этом среднее значение государственной поддержки в 2017 году является самым максимальным.
# - Всего с 2013 года 332 российских фильма получили государственную поддрежку на сумму более 20 млрд руб.
# - Средняя доля государственной поддержки в общем бюджете фильмов составляет 47%. Доля колеблется год от года, дотсигает пика в 2016 году (57%). Минимальное значение в 2019 году - 39%
# - До 2016 года суммарные бюджеты фильмов с государственной поддрежкой были выше общих сборов. Ситуация изменилась в 2017-2018 гг. когда фильмы стали собирать больше затраченных на их производство средств
# - Всего у 79 фильмов с гос поддержкой из 332 сборы были выше затрат и наибольшее количество таких фильмов вышло в прокат в 2015 и 2018 гг. (18 и 20 фильмов соответственно).
# - Наивысшие оценки получают отечественные фильмы в жанрах "криминал", "детский" и "спорт"
# - Но для фильмов с господдрежкой и тех, которые заработали больше чем потратили, максимальные баллы в других жанрах - боевик, биография, приключения.
#
# 2.6) Оценка эффективности вложений в увеличение рейтинга:
# - предложен метод рассчета и оценка ежегодных вложений в бюджет произведения, для увеличения рейтинга на Кинопоиске, а также оценка эффекта в  виде доп сборов за счет увеличения рейтинга произведения на 1 балл.
#
# **В рамках работы:**
#
# - повторил основы предобработки данных
# - порассуждал на тему что можно заменить, а что нельзя
# - применил подход "против лома нет приема" -  ручная замена некоторых значений
# - нашел ряд взаимосвязей и корреляций
# - пару раз сглупил, но вроде бы исправился
# - шутканул
# - написал пару функций
# - более-менее понял, как стоить графики .plot()  и из seaborn
# - "виртуозно" и непоследовательно приенял разичные способы агрегации данных
#
# **Рекомендации для Минкультуры РФ**:
#
# Анализ ретроспективных данных о выдаче прокатных удостоверений и сборах показал, что с 2013 года государством применяются ощутимые меры по поддержке отечественного кинематографа. Ежегодно увеличивается поддержка в виде предоставления государственных средств на спонсирование производства отчетсвенного кино, в т.ч. в виде возвратных средств. Меры принимаемые Правительством РФ можно назвать эффективными, т.к. с 2016 года кинопродукция, производимая в т.ч. за счет бюджета вышла на самоокупаемость, т.е сборы от проката превышают бюджет - затраты на производство.
#
# Для сохранения темпов роста отечественной киноиндустрии, а также повышения эффективности государственного управления в сфере, рекомендуется:
#
# - обратить внимание на государственную поддержку произведений кинематографа в жанрах "боевик", "биография", "приключения" и "спорт", как на самые популярные и восстребованные жанры отечественного кино.
# - обратить внимание на государственную поддержку произведений кинематографа в жанрах "спорт", "комедия", "драма", "мультфильм", как одних из самых "эластичных по господдрежке для увеличения рейтинга <=> популярности". ПО прдеварительным расчетам 1 руб. гос финансирования фильма в жанре спорт может дать доп 7 руб. доп. доходов в виде сборов => 1,26 руб. в виде НДС дополнительных налоговых доходов в бюджет

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все перечитал, проверил, все окей. Да, ты большой молодец. ПРоделана огромная работа!

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Очень хотелось получить некие регрессионные уравнения, например:
#
# - зависимость сборов от гос.поддержки
# - зависимость сборов от гос.поддрежки в разрезе жанров
#
# Мы это получили в общем виде коэффициентами корреляции и диаграммами, но хотелось бы получить уравнение.
#
# Например, seаborn умеет строить график линии регрессии, но не отображает уравнение. Конечно вы скажете, что регрессоры можно посчитать и просто так без визуализации, но разме во всемогущем питоне нет обычного метода в стандартной библиотеке, который бы возвращал зависимость между двум переменными. А говорили, что круче экселя))
#
# + Согласитесь. что для п.4.3.3. очень даже подойдут знания постороения регрессионных моделей, да, хотябы понимания, как уравнение получить=) придется в Orange по старинке делать, увы
#
# </div>

# %%
sns.lmplot(x='state_support', y='box_office', data=support_movies)

# %% [markdown]
# <div class="alert alert-info"> <b>  Комментарии студента:</b> Seaborn lmplot или regplot рисует линию регрессии (тренда), но не возвращает уравнение. прошу написать директору seborna, чтобы исправил (выделено красным). В обсуждении в Slack наставник предложил numpy.polyfit, которая возвращает уравнение полинома, но это не то пальто. Вобщем, прошу подсказки
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Оу, а я тоже делаю через numpy.polyfit. Подумаю о дургих методах и через куратора тебе отпишусь)

# %% [markdown]
# <div class="alert alert-info"> <b>  Комментарии студента:</b> Можно сделать отдельный вывод по киностудии им. Джон Доу. На Ваше усмотрение.
#
# И напишите, пжлст, директору Юпитера, чтобы сделал функционал по выделению ошибок в тексте, а то незвзможнзо...
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Принято, все передам 😂

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#  Борис, спасибо за  проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# **Отмечу положительные моменты**:
#
#     1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть
#
#     2. Отличные визуализации
#
#     2. На разных шагах проект ты предлагала очень интересные решения и методы для их реализации. Хорошая работа!
#
#
# **На что стоит обратить внимание**:
#
#     1. Пока даже не знаю, на что. Вижу, что твои знания опережают наш курс, похоже, что ты человек подготовленный) ЧТож, дальше буду тнамного сложнее проекты, там ты точно не заскучаешь
#
#
# **Удачи и увидимся на просторах Практикума!**

# %% [markdown]
# <image src="https://www.meme-arsenal.com/memes/a4228aa654885d5d1546bfd9d4929c48.jpg" alt="Дружко">
